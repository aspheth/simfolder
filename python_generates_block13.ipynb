# %% [markdown]
# <a href="https://colab.research.google.com/github/aspheth/simfolder/blob/master/python_generates_block13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for start in range(len(lst)):
    for stop in range(start + 1, min(start + lim + 1, len(lst) + 1)):
        print(lst[start:stop])

# %%
list1 = [1, 2, 3, 4, 5]
list2 = [10, 20, 30, 40, 50]
list3 = [100, 200, 300, 400, 500]

# %%
add_lists = lambda a, b, c: a * b + c

# %%
def sum_of_lists(*args,func = None ):
