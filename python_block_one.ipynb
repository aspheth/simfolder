# %% [markdown]
# <a href="https://colab.research.google.com/github/aspheth/simfolder/blob/master/python_block_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ПЕРЕМЕННЫЕ БАЗОВЫЕ ТИПЫ ДАННЫХ

# %%
x = 10
x
# Out:
# 10

# %%
y = 3
y
t  = type(y)
t
# Out:
# int

# %%
"""Введите свой код ниже"""
t = 2e-5
float(t)
# Out:
# 2e-05

# %%
from math import pi

# %%
a = pi
a
# Out:
# 3.141592653589793

# %%
rou_a = round(a,10)
rou_a
t_rounded = round(rou_a,3)
t_rounded
# Out:
# 3.142

# %%
from math import floor
t= 2.71828
t
ft = floor(t)
ft
# Out:
# 2

# %%
c=5+3j
c1=0+1j
c2=6+0j

# %%
c=5+3j
c.real
c.imag
# Out:
# 3.0

# %%
conj_c = c.conjugate()
conj_c
# Out:
# (5-3j)

# %%
c = 1
float(c)
c1 = 2.5
int(c1)
# Out:
# 2

# %%
c=10
c/=2
c+=1

# %%
s = 'my string'
s
# Out:
# 'my string'

# %%
s = 'a'
s * 100
# Out:
# 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa'

# %%
s1 = 'my'
s2 = 'function'
s1 + ' '  + s2
# Out:
# 'my function'

# %%
s = 1e-5
s
str(s)
# Out:
# '1e-05'

# %%
s = 1e-5
float(s)
# Out:
# 1e-05

# %%
s = len('this is a very long sentence')
s
# Out:
# 28

# %%
s = 'он сказал: "привет!"'
s
# Out:
# 'он сказал: "привет!"'

# %%
s='сначала сделаем \tтабуляцию\nа теперь перейдем на новую строку'
s
# Out:
# 'сначала сделаем \tтабуляцию\nа теперь перейдем на новую строку'

# %%
s = '''
это первая строка
это вторая строка
это третья строка
'''
s
# Out:
# '\nэто первая строка\nэто вторая строка\nэто третья строка\n'

# %%
num =5
s = f'это число {num}'
s
# Out:
# 'это число 5'

# %%
num = 5
s1 = 'Это'
s = '{} число {}'.format(s1,num)
s
# Out:
# 'Это число 5'

# %%
'      это строка    с большими пробелами      '.strip()
# Out:
# 'это строка    с большими пробелами'

# %%
s = 'это строка, где, много очень, лишних, запятых, ,'
s.split(',')
# Out:
# ['это строка', ' где', ' много очень', ' лишних', ' запятых', ' ', '']

# %%
s = 'БУквЫ В рАЗных РЕГИстрах'
s.lower()
s.upper()
'БУквЫ В рАЗных РЕГИстрах'.swapcase()
# Out:
# 'буКВы в РазНЫХ региСТРАХ'

# %%
s = 'Просто еще одна обычная строка'
s
s.split()
''.join(s)
'-'.join(s)
# Out:
# 'П-р-о-с-т-о- -е-щ-е- -о-д-н-а- -о-б-ы-ч-н-а-я- -с-т-р-о-к-а'

# %%
s = 'Просто еще одна обычная строка'
s.startswith('еще')
s.endswith('ока')
# Out:
# True

# %%
s = 'это повтор повтор и еще повтор'
s.find('повтор',5)
# Out:
# 11

# %%
s = 'это начальная строка'
s = s[5:11]
s
# Out:
# 'ачальн'

# %%
'это начальная строка'[::-1]
# Out:
# 'акортс яаньлачан отэ'

# %%
s = 'это начальная строка и еще одна строка'
s.replace('строка',"строчка")
# Out:
# 'это начальная строчка и еще одна строчка'

# %%
res = '-'.join(s.strip().replace('code','my_code').split())[::-1]
res
# Out:
# 'акортс-андо-еще-и-акортс-яаньлачан-отэ'
