# %% [markdown]
# <a href="https://colab.research.google.com/github/aspheth/simfolder/blob/master/python_11_exceptions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ЛЕКЦИИ
и

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_1201/2354412189.py in <cell line: 0>()
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
len(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1201/2982808344.py in <cell line: 0>()
# ----> 1 len(1)
#
# TypeError: object of type 'int' has no len()

# %%
try:
  # КОДw
except:
  # СРАБОТАЕ ПРИ ОШИБКЕ

# %%
def foo(a,b):
  try:
    return a/b
  except:
    print(f'Произошла ошибька. а = {a}, b = {b}')

# %%
foo(1,1)
# Out:
# 1.0

# %%
foo(1,0)
# Out:
# Произошла ошибька. а = 1, b = 0

# %%
try:
  1/0
except Exception as err:
  print(err)
# Out:
# division by zero
