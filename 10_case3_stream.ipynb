# %% [markdown]
# <a href="https://colab.research.google.com/github/aspheth/simfolder/blob/master/10_case3_stream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls
# Out:
# sample_data/

# %%
pwd
# Out:
# '/content'

# %%
# !wget https://gist.github.com/Vs8th/739269a03f2f4a7396d04d6739da3771/raw/registrations.csv

# !wget https://gist.github.com/Vs8th/aacb80595d1d6aaa2e31eb735f8bc644/raw/entries.csv

# !wget https://gist.github.com/Vs8th/0e827e9a608117345dd6585ab81e8c86/raw/metrics.txt
# Out:
# --2026-05-23 21:45:59--  https://gist.github.com/Vs8th/739269a03f2f4a7396d04d6739da3771/raw/registrations.csv
# Resolving gist.github.com (gist.github.com)... 140.82.113.3
# Connecting to gist.github.com (gist.github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/739269a03f2f4a7396d04d6739da3771/raw/registrations.csv [following]
# --2026-05-23 21:45:59--  https://gist.githubusercontent.com/Vs8th/739269a03f2f4a7396d04d6739da3771/raw/registrations.csv
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14918 (15K) [text/plain]
# Saving to: ‘registrations.csv’
#
# registrations.csv   100%[===================>]  14.57K  --.-KB/s    in 0s
#
# ...

# %%
ls
# Out:
# entries.csv  metrics.txt  registrations.csv  sample_data/

# %%
with open ('entries.csv','r') as ef:
  entrlst = ef.readlines()

# %%
for x in entrlst[:4]:
  print(x)
# Out:
# user_id;entry_date
#
# 1;2021-01-01
#
# 2;2021-01-01
#
# 3;2021-01-01

# %%
type(entrlst)
# Out:
# list

# %%
with open('registrations.csv','r') as rf:
  reglst = rf.readlines()
  print(reglst[:4])
# Out:
# ['user_id;registration_date\n', '1;2021-01-01\n', '2;2021-01-01\n', '3;2021-01-01\n']

# %%
regs = []
for line in reglst:
    if '2021-01' in line and 'user_id' not in line:  # пропускаем заголовок
        user_id, date_str = line.strip().split(';')
        regs.append((int(user_id), (datetime.strptime(date_str, '%Y-%m-%d')).date()))

# %%
regs

# %%
entrs = []
for line in entrlst:
  if 'user_id' not in line:
        user_id, date_str = line.strip().split(';')
        entrs.append((int(user_id), (datetime.strptime(date_str, '%Y-%m-%d')).date()))

# %%
from datetime import datetime

# %%
entrs

# %%
retention_15_day = 0
entrs = set(entrs)
for x in regs:
  for y in entrs:
    if x[0] == y[0] and (y[1] - x[1]).days == 15:
      retention_15_day += 1

# %%
retention_15_day = round((retention_15_day / len(regs))*100,5)

# %%
retention_15_day
# Out:
# 54.65116

# %%
entrs = set(entrs)

# %%
entrs = list(entrs)
