# %% [markdown]
# <a href="https://colab.research.google.com/github/aspheth/simfolder/blob/master/python_func_prog_block11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
foo = lambda x: x + 5

# %%
foo (4)
# Out:
# 9

# %%
foo = lambda x,y: {f'x{x}':y}

# %%
foo(1,2)
# Out:
# {'x': 2}

# %%
a = {}
for x in range(1,6):
  y=x
  a.update(foo(x,y))

# %%
a
# Out:
# {'x1': 1, 'x2': 2, 'x3': 3, 'x4': 4, 'x5': 5}

# %%
foo
# Out:
# <function __main__.<lambda>(x, y)>

# %%
lst = [1,2,3,4,5,6]

# %%
res = []
for el in lst:
  if el % 2 == 0:
    res.append(el)

# %%
res
# Out:
# [2, 4, 6]

# %%
res = filter(lambda x: x % 2 == 0, lst)

# %%
print(list)

# %%
lst = [1,2,3,4,5,6]
list(filter(lambda x: x % 2 == 0, lst))
# Out:
# [2, 4, 6]

# %%
type(filter)
# Out:
# type

# %%
import builtins
filter = builtins.filter

# %%
import builtins

# Восстанавливаем filter
filter = builtins.filter

lst = [1, 2, 3, 4, 5, 6]
result = list(filter(lambda x: x % 2 == 0, lst))
print(result)  # [2, 4, 6]
# Out:
# [2, 4, 6]

# %%
list(filter(lambda x: x == 1,lst))
# Out:
# [1]

# %%
filter
# Out:
# filter

# %%
lst = [1, 2, 3, 4, 5, 6]

# %%
res = []
for x in lst:
  res.append(x**2)

# %%
res
# Out:
# [1, 4, 9, 16, 25, 36]
