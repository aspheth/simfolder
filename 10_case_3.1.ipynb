# %% [markdown]
# <a href="https://colab.research.google.com/github/aspheth/simfolder/blob/master/10_case_3.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime

# %%
# !wget https://gist.github.com/Vs8th/739269a03f2f4a7396d04d6739da3771/raw/registrations.csv

# !wget https://gist.github.com/Vs8th/aacb80595d1d6aaa2e31eb735f8bc644/raw/entries.csv

# !wget https://gist.github.com/Vs8th/0e827e9a608117345dd6585ab81e8c86/raw/metrics.txt
# Out:
# --2026-05-26 11:20:51--  https://gist.github.com/Vs8th/739269a03f2f4a7396d04d6739da3771/raw/registrations.csv
# Resolving gist.github.com (gist.github.com)... 20.27.177.113
# Connecting to gist.github.com (gist.github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/739269a03f2f4a7396d04d6739da3771/raw/registrations.csv [following]
# --2026-05-26 11:20:51--  https://gist.githubusercontent.com/Vs8th/739269a03f2f4a7396d04d6739da3771/raw/registrations.csv
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14918 (15K) [text/plain]
# Saving to: ‘registrations.csv’
#
# registrations.csv   100%[===================>]  14.57K  --.-KB/s    in 0.002s
#
# 2026-05-26 11:20:52 (9.48 MB/s) - ‘registrations.csv’ saved [14918/14918]
#
# --2026-05-26 11:20:52--  https://gist.github.com/Vs8th/aacb80595d1d6aaa2e31eb735f8bc644/raw/entries.csv
# Resolving gist.github.com (gist.github.com)... 20.27.177.113
# Connecting to gist.github.com (gist.github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/aacb80595d1d6aaa2e31eb735f8bc644/raw/entries.csv [following]
# --2026-05-26 11:20:52--  https://gist.githubusercontent.com/Vs8th/aacb80595d1d6aaa2e31eb735f8bc644/raw/entries.csv
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 308588 (301K) [text/plain]
# Saving to: ‘entries.csv’
#
# entries.csv         100%[===================>] 301.36K  --.-KB/s    in 0.1s
#
# 2026-05-26 11:20:52 (2.98 MB/s) - ‘entries.csv’ saved [308588/308588]
#
# --2026-05-26 11:20:52--  https://gist.github.com/Vs8th/0e827e9a608117345dd6585ab81e8c86/raw/metrics.txt
# Resolving gist.github.com (gist.github.com)... 20.27.177.113
# Connecting to gist.github.com (gist.github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/0e827e9a608117345dd6585ab81e8c86/raw/metrics.txt [following]
# --2026-05-26 11:20:52--  https://gist.githubusercontent.com/Vs8th/0e827e9a608117345dd6585ab81e8c86/raw/metrics.txt
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67 [text/plain]
# Saving to: ‘metrics.txt’
#
# metrics.txt         100%[===================>]      67  --.-KB/s    in 0s
#
# 2026-05-26 11:20:53 (1007 KB/s) - ‘metrics.txt’ saved [67/67]

# %%
with open ('entries.csv','r') as ef:
  entrlst = ef.readlines()

# %%
with open('registrations.csv','r') as rf:
  reglst = rf.readlines()

# %%
regs = []
for line in reglst:
    if '2021-01' in line and 'user_id' not in line:  # пропускаем заголовок
        user_id, date_str = line.strip().split(';')
        regs.append((int(user_id), (datetime.strptime(date_str, '%Y-%m-%d')).date()))

# %%
entrs = []
for line in entrlst:
  if 'user_id' not in line:
        user_id, date_str = line.strip().split(';')
        entrs.append((int(user_id), (datetime.strptime(date_str, '%Y-%m-%d')).date()))

# %%
retention_15_day = 0
entrs = set(entrs)
for x in regs:
  for y in entrs:
    if x[0] == y[0] and (y[1] - x[1]).days == 15:
      retention_15_day += 1

# %%
retention_15_day = round((retention_15_day / len(regs))*100,5)

# %%
retention_15_day
# Out:
# 54.65116
