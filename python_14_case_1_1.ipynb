# %% [markdown]
# <a href="https://colab.research.google.com/github/aspheth/simfolder/blob/master/python_14_case_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls
# Out:
# auto_purchase.log  sample_data/

# %%
# !wget https://gist.github.com/Vs8th/38d5d914171c84166728a9746d212bad/raw/auto_purchase.log
# Out:
# --2026-06-17 13:49:05--  https://gist.github.com/Vs8th/38d5d914171c84166728a9746d212bad/raw/auto_purchase.log
# Resolving gist.github.com (gist.github.com)... 140.82.114.3
# Connecting to gist.github.com (gist.github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/38d5d914171c84166728a9746d212bad/raw/auto_purchase.log [following]
# --2026-06-17 13:49:05--  https://gist.githubusercontent.com/Vs8th/38d5d914171c84166728a9746d212bad/raw/auto_purchase.log
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 459418 (449K) [text/plain]
# Saving to: ‘auto_purchase.log’
#
# auto_purchase.log   100%[===================>] 448.65K  --.-KB/s    in 0.04s
#
# 2026-06-17 13:49:05 (12.1 MB/s) - ‘auto_purchase.log’ saved [459418/459418]

# %%
with open('auto_purchase.log', 'r') as f:
  lines = list(f.readlines())

# %%
lines[:30]
# Out:
# ['INFO  | 2022-07-19 16:46:43,708  | file: demon_auto_purchase_bundle.py |  line: 44 | [demon] Поверяем истекающие премиум-пакеты\n',
#  'INFO  | 2022-07-19 16:46:43,722  | file: demon_auto_purchase_bundle.py |  line: 54 | [demon] Cегодня 2022-07-19, количество людей с автопродлением подписки: 1\n',
#  'INFO  | 2022-07-19 16:46:43,723  | file: demon_auto_purchase_bundle.py |  line: 61 | [demon] Обновляем подписку пользователю id: 63, payment_method_id: 2a68f0fe\n',
#  'INFO  | 2022-07-19 17:05:32,925  | file: demon_auto_purchase_bundle.py |  line: 44 | [demon] Поверяем истекающие премиум-пакеты\n',
#  'INFO  | 2022-07-19 17:05:32,944  | file: demon_auto_purchase_bundle.py |  line: 54 | [demon] Cегодня 2022-07-19, количество людей с автопродлением подписки: 1\n',
#  'INFO  | 2022-07-19 17:05:32,947  | file: demon_auto_purchase_bundle.py |  line: 61 | [demon] Обновляем подписку пользователю id: 63, payment_method_id: 2a68f0fe\n',
#  'INFO  | 2022-07-20 00:01:02,711  | file: demon_auto_purchase_bundle.py |  line: 44 | [demon] Поверяем истекающие премиум-пакеты\n',
#  'INFO  | 2022-07-20 00:01:02,728  | file: demon_auto_purchase_bundle.py |  line: 54 | [demon] Cегодня 2022-07-20, количество людей с автопродлением подписки: 0\n',
#  'INFO  | 2022-07-20 00:01:02,730  | file: demon_auto_purchase_bundle.py |  line: 57 | [demon] Выход из программы\n',
#  'INFO  | 2022-07-21 00:01:02,244  | file: demon_auto_purchase_bundle.py |  line: 44 | [demon] Поверяем истекающие премиум-пакеты\n',
#  'INFO  | 2022-07-21 00:01:02,262  | file: demon_auto_purchase_bundle.py |  line: 54 | [demon] Cегодня 2022-07-21, количество людей с автопродлением подписки: 0\n',
#  'INFO  | 2022-07-21 00:01:02,264  | file: demon_auto_purchase_bundle.py |  line: 57 | [demon] Выход из программы\n',
#  'INFO  | 2022-07-22 00:01:02,271  | file: demon_auto_purchase_bundle.py |  line: 44 | [demon] Поверяем истекающие премиум-пакеты\n',
#  'INFO  | 2022-07-22 00:01:02,286  | file: demon_auto_purchase_bundle.py |  line: 54 | [demon] Cегодня 2022-07-22, количество людей с автопродлением подписки: 0\n',
#  'INFO  | 2022-07-22 00:01:02,288  | file: demon_auto_purchase_bundle.py |  line: 57 | [demon] Выход из программы\n',
#  'INFO  | 2022-07-23 00:01:02,312  | file: demon_auto_purchase_bundle.py |  line: 44 | [demon] Поверяем истекающие премиум-пакеты\n',
#  'INFO  | 2022-07-23 00:01:02,329  | file: demon_auto_purchase_bundle.py |  line: 54 | [demon] Cегодня 2022-07-23, количество людей с автопродлением подписки: 0\n',
#  'INFO  | 2022-07-23 00:01:02,332  | file: demon_auto_purchase_bundle.py |  line: 57 | [demon] Выход из программы\n',
#  'INFO  | 2022-07-24 00:01:02,612  | file: demon_auto_purchase_bundle.py |  line: 44 | [demon] Поверяем истекающие премиум-пакеты\n',
#  'INFO  | 2022-07-24 00:01:02,630  | file: demon_auto_purchase_bundle.py |  line: 54 | [demon] Cегодня 2022-07-24, количество людей с автопродлением подписки: 0\n',
#  'INFO  | 2022-07-24 00:01:02,632  | file: demon_auto_purchase_bundle.py |  line: 57 | [demon] Выход из программы\n',
#  'INFO  | 2022-07-25 00:01:02,674  | file: demon_auto_purchase_bundle.py |  line: 44 | [demon] Поверяем истекающие премиум-пакеты\n',
#  'INFO  | 2022-07-25 00:01:02,699  | file: demon_auto_purchase_bundle.py |  line: 54 | [demon] Cегодня 2022-07-25, количество людей с автопродлением подписки: 0\n',
#  'INFO  | 2022-07-25 00:01:02,702  | file: demon_auto_purchase_bundle.py |  line: 57 | [demon] Выход из программы\n',
#  'INFO  | 2022-07-26 00:01:03,416  | file: demon_auto_purchase_bundle.py |  line: 44 | [demon] Поверяем истекающие премиум-пакеты\n',
#  'INFO  | 2022-07-26 00:01:03,447  | file: demon_auto_purchase_bundle.py |  line: 54 | [demon] Cегодня 2022-07-26, количество людей с автопродлением подписки: 0\n',
#  'INFO  | 2022-07-26 00:01:03,453  | file: demon_auto_purchase_bundle.py |  line: 57 | [demon] Выход из программы\n',
#  'INFO  | 2022-07-27 00:01:02,656  | file: demon_auto_purchase_bundle.py |  line: 44 | [demon] Поверяем истекающие премиум-пакеты\n',
#  'INFO  | 2022-07-27 00:01:02,679  | file: demon_auto_purchase_bundle.py |  line: 54 | [demon] Cегодня 2022-07-27, количество людей с автопродлением подписки: 0\n',
#  'INFO  | 2022-07-27 00:01:02,683  | file: demon_auto_purchase_bundle.py |  line: 57 | [demon] Выход из программы\n']
