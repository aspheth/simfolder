# %% [markdown]
# <a href="https://colab.research.google.com/github/aspheth/simfolder/blob/master/python_fincts_block4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Python ДЗ 3: Приветствие

# %%
name = input()
def greeting(name):
  return f'Hello, {name}'
# Out:
# Dime

# %%
greeting(name)
# Out:
# 'Hello, Dime'

# %%
#Python ДЗ 3: Аргументы по умолчанию

# %%
def employee(name,zp = 9000 ):
  return f'{name,zp}'

# %%
employee(name)
# Out:
# "('Dime', 9000)"

# %%
#Python ДЗ 3: Возвращаемое значение функции

# %%
def always500(*asd):
  return 500

# %%
always500()
# Out:
# 500

# %%
digit = input()
# Out:
# 3456677

# %%
def digit_sum(digit):
  sum = 0
  for x in list(digit):
    sum += int(x)
  return sum

# %%
list(digit)
# Out:
# ['1', '2', '3', '4']

# %%
sum = 0
for x in list(digit):
  sum += int(x)

# %%
digit = input()
digit_sum(digit)
# Out:
# 66778
# 34

# %%
#Python ДЗ 3: Среднее арифметическое

# %%
del sum
def average(*a):
  return sum(a)/len(a)

# %%
average(1,4,535,65,7,)
# Out:
# 122.4

# %%
#Python ДЗ 3: Последовательность функций

# %%
'int' object is not callable
# Out:
#   File "/tmp/ipykernel_3267/1528567302.py", line 1
#     'int' object is not callable
#           ^
# SyntaxError: invalid syntax

# %%
def func1(a):
  return a + 5

def func2(b):
  return func1(b)*2

# %%
func1(1)
# Out:
# 6

# %%
func2(2)
# Out:
# 14
