# %%
# СЛОЖНЫЕ ТИПЫ ДАННЫХ

# %%
#Python ДЗ 1: Аналитика по классу

# %%
grades = [3, 5, 3, 2, 3, 4, 5]
fives = grades.count(5)
threes = grades.count(3)

f'На этой неделе было {round(threes * 100/len(grades),2)}% троек и {round(fives * 100/len(grades),2)}% пятерок'
# Out:
# 'На этой неделе было 42.86% троек и 28.57% пятерок'

# %%
#Python ДЗ 1: Поставки в магазин

# %%
current = ['Молоко', 'Хлеб', 'Яйца', 'Сахар', 'Соль']
postavka = ['Мука', 'Рис', 'Спагетти', 'Картофель', 'Лук']
a = 'Кофе'

# %%
current.append(postavka)
postavka.clear()
postavka.append(a)
postavka
# Out:
# ['Кофе']

# %%
current
# Out:
# ['Молоко',
#  'Хлеб',
#  'Яйца',
#  'Сахар',
#  'Соль',
#  ['Кофе'],
#  ['Кофе'],
#  ['Кофе'],
#  ['Кофе']]

# %%
#Python ДЗ 1: Обслуживание очереди

# %%
queue = ['Алиса', 'Константин', 'Алексей']
queue
# Out:
# ['Алиса', 'Константин', 'Алексей']

# %%
a = queue.pop(0)
f'Ослужен клиент: {a}'
queue.append('Давид')
queue.append('Ева')
a = queue.pop(0)
f'Ослужен клиент: {a}'
# Out:
# 'Ослужен клиент: Константин'

# %%
queue
# Out:
# ['Алексей', 'Давид', 'Ева']

# %%
#Python ДЗ 1: Обновление корзины

# %%
cart = []
a = 'grill'

b = ['garlic sauce', 'sweet mustard sauce']

c = 'meat'

# %%
cart.append(a)
cart1 = cart.copy()
cart1
# Out:
# ['grill']

# %%
cart1.extend(b)

# %%
cart1
# Out:
# ['grill', 'garlic sauce', 'sweet mustard sauce']

# %%
cart2 = cart1.copy()

# %%
ind = cart2.index(b[0])

# %%
cart2.insert(ind,c)

# %%
cart2
# Out:
# ['grill', 'meat', 'garlic sauce', 'sweet mustard sauce']

# %%
#Python ДЗ 1: Исправляем оценки

# %%
grades = [2, 5, 4, 6, 3]

# %%
grades_correct = grades.copy()

# %%
grades_correct.index(6)
grades_correct[grades_correct.index(6)] = 5
grades_correct.sort()

# %%
grades_correct.insert(0,5)

# %%
grades_correct
# Out:
# [5, 2, 3, 4, 5, 5]

# %%
grades_correct.sort(reverse = True)
grades_correct
# Out:
# [5, 5, 5, 4, 3, 2]

# %%
#Python ДЗ 1: Создадим город

# %%
city_name = 'Москва'
city_year = 1147

# %%
city = city_name,city_year

# %%
city
# Out:
# ('Москва', 1147)

# %%
#Python ДЗ 1: Посетители банка

# %%
visitors1 = (45, 10, 39, 51, 42, 38, 49)
visitors2 = (65, 14, 33, 11, 43, 44, 12)
visitors3 = (44, 45, 22, 15, 43, 22, 78)
visitors4 = (43, 33, 11, 7, 34, 31, 49)

# %%
f'минимальное количество посетителей: {min(visitors1 + visitors2 + visitors3 + visitors4)}'
# Out:
# 'минимальное количество посетителей: 7'

# %%
f'максимальное количество посетителей: {max(visitors1 + visitors2 + visitors3 + visitors4)}
# Out:
# 78

# %%
f'суммарное число посетителей: {sum(visitors1 + visitors2 + visitors3 + visitors4)}'
# Out:
# 'суммарное число посетителей: 973'

# %%
res = ((visitors1 + visitors2 + visitors3 + visitors4).index(max(visitors1 + visitors2 + visitors3 + visitors4)))

# %%
res
# Out:
# 20

# %%
#Python ДЗ 1: Библиотека будущего

# %%
author_data = ('Булгаков', 1991, 'Киев')
author = list(author_data)
author[author.index(1991)] = 1891
author_data = tuple(author)

# %%
#Python ДЗ 1: Обновление склада

# %%
#1

# %%
store = (['кока-кола', 42], ['вода', 60], ['кофе', 15], ['чай', 35], ['сок', 23])

# Введите ваше решение ниже

store[0][1] -=15
store[1][1] -=15
store[2][1] -=15
store[3][1] -=15
store[4][1] -=15
new_store = list(store)
a,b = new_store.pop(2)
needed = (a,)
new_store = tuple(new_store)

# %%
#2

# %%
store= (['кока-кола', 42], ['вода', 60], ['кофе', 15], ['чай', 35], ['сок', 23])
store
# Out:
# (['кока-кола', 42], ['вода', 60], ['кофе', 15], ['чай', 35], ['сок', 23])

# %%
new_store = []
needed = []

# %%
for i in list(store):
  i[1] -= 15
  if i[1]>0:
    new_store.append(i)
  else:
    needed.append(i)

# %%
tuple(new_store)
tuple(needed)
# Out:
# (['кофе', 0],)

# %%
#Python ДЗ 1: Олимпийские игры

# %%
olympics = (
    ('UK', 1908), ('Germany', 1908), ('UK', 1920), ('Sweden', 1920),
    ('Austria', 1924), ('Norway', 1924), ('Austria', 1928), ('USA', 1932),
    ('Norway', 1932), ('Germany', 1936), ('UK', 1936), ('USA', 1948),
    ('Canada', 1948), ('USA', 1952), ('UK', 1952), ('USA', 1956),
    ('USA', 1960), ('Netherlands', 1960), ('Czechoslovakia', 1964), ('USA', 1964),
    ('USA', 1968), ('East Germany', 1968), ('Austria', 1972), ('USA', 1972),
    ('East Germany', 1976), ('USA', 1976), ('East Germany', 1980), ('USA', 1980),
    ('East Germany', 1984), ('USA', 1984), ('East Germany', 1988), ('USA', 1988),
    ('Japan', 1992), ('USA', 1992), ('Ukraine', 1994), ('Germany', 1994),
    ('USA', 1998), ('Russia', 1998), ('USA', 2002), ('Russia', 2002),
    ('Japan', 2006), ('USA', 2006), ('South Korea', 2010), ('Japan', 2010),
    ('South Korea', 2014), ('Russia', 2014), ('Russia', 2018), ('Italy', 2018),
    ('Russia', 2022), ('Japan', 2022))

# %%
#1

# %%
ru = 0
au = 0
usa = 0
sw = 0

for x , y in olympics:
  if x == 'Russia':
    ru += 1
  elif x == 'Austria':
    au += 1
  elif x == 'USA':
    usa += 1
  elif x == 'Sweden':
    sw += 1

# %%
res = ()
res = (['Russia',ru],['Austra',au],['USA',usa],['Sweden',sw])

# %%
res
# Out:
# (['Russia', 5], ['Austra', 3], ['USA', 16], ['Sweden', 1])

# %%
#2
# Введите ваше решение ниже
ru = olympics.count('Russia')
au = olympics.count('Austria')
usa =olympics.count('USA')
ge = olympics.count('Germany')
res=(['Russia',ru],['Austria',au],['USA',usa],['Germany',ge])

# %%
res
# Out:
# (['Russia', 0], ['Austria', 0], ['USA', 0], ['Germany', 0])

# %%
#Python ДЗ 1: Сравнение множеств

# %%
a = {1, 2}
b = {1, 5}
c = {4, 5}

# %%
a.isdisjoint(b)
# Out:
# False

# %%
f'''3 данных множества имеют общие элементы:
A и B: {not a.isdisjoint(b)}
A и C: {not a.isdisjoint(c)}
B и C: {not b.isdisjoint(c)}
'''
# Out:
# '3 данных множества имеют общие элементы:\nA и B: True\nA и C: False\nB и C: True\n'

# %%
#Python ДЗ 1: Совпадение хобби

# %%
person1 = {'painting', 'movies'}
person2 = {'programming', 'movies'}

# %%
person1.difference(person2)
# Out:
# {'painting'}

# %%
a = len(person1.intersection(person2))
a
# Out:
# 1

# %%
round(len(person1.intersection(person2))/len(person1.union(person2))*100,2)
# Out:
# 33.33

# %%
#Python ДЗ 1: Прочитанные книги

# %%
student1 = {'Мастер и Маргарита', 'Герой нашего времени', 'Отцы и дети'}
student2 = {'Мастер и Маргарита', 'Евгений Онегин', 'Герой нашего времени', 'Отцы и дети'}

# %%
diff= sorted(list(student2.difference(student1)),reverse = True)

# %%
#Python ДЗ 1: Уникальные символы

# %%
a = 'Set'
b = 'Test'

# %%
len(set(a.lower()).union(set(b.lower())))
# Out:
# 3

# %%
#Python ДЗ 1: Время подачи заказа

# %%
lunch_menu = {"hamburger", "fries", "salad", "soup", "soft drink"}

dinner_menu = {"steak", "chicken", "pasta", "salad", "vegetables", "wine"}

# %%
customer_order = {"hamburger", "fries", "salad"}

# %%
customer_order.issubset(lunch_menu)
# Out:
# True

# %%
f"Ваш заказ может быть подан на обед: {customer_order.issubset(lunch_menu)} "
# Out:
# 'Ваш заказ может быть подан на обед: True '

# %%
f"Ваш заказ может быть подан на ужин: {customer_order.issubset(dinner_menu)} "
# Out:
# 'Ваш заказ может быть подан на ужин: False '

# %%
#Python ДЗ 1: Пары ключ-значение

# %%
a = {1:1,2:2,3:3}
a
# Out:
# {1: 1, 2: 2, 3: 3}

# %%
a.items()
# Out:
# dict_items([(1, 1), (2, 2), (3, 3)])

# %%
a.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
list(a.items())
# Out:
# [(1, 1), (2, 2), (3, 3)]

# %%
#Python ДЗ 1: Работа со словарем

# %%
dict={"name": "Marc", "eyes": "blue", "height": 185, "weight": 85}

# %%
dict['height'] = dict['height']+2

# %%
dict['height']
# Out:
# 187

# %%
dict['work'] = "accountant"

# %%
dict
# Out:
# {'name': 'Marc',
#  'eyes': 'blue',
#  'height': 187,
#  'weight': 85,
#  'work': 'accountant'}

# %%
#Python ДЗ 1: Определитель месяца

# %%
dic = {'1': 'Январь', 2: 'Февраль', '3': 'Март', '4': 'Апрель', '5': 'Май', '6': 'Июнь', '7': 'Июль', '8': 'Август', '9': 'Сентябрь',
       '10': 'Октябрь', '11': 'Ноябрь', '12': 'Декабрь'}

num = input()
if 0 > int(num) or int(num) > 12:
  print('Введите число от 1 до 12')
print (f'{dic[num]}')
# Out:
# 3
# Март

# %%
#Python ДЗ 1: Траты по категориям

# %%
january_spendings = {"CategoryA": 100, "CategoryB": 200}
february_spendings = {"CategoryB": 150, "CategoryC": 250}
march_spendings = {"CategoryF": 400, "CategoryA": 120}

# %%
common_spendings = {}

# %%
common_spendings.update(february_spendings)

# %%
common_spendings.update(march_spendings)

# %%
common_spendings
# Out:
# {'CategoryB': 150, 'CategoryC': 250, 'CategoryF': 400, 'CategoryA': 120}
