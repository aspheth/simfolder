# %% [markdown]
# <a href="https://colab.research.google.com/github/aspheth/simfolder/blob/master/python_case_2_stream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# %%
# !wget https://gist.github.com/Vs8th/d0bd4bdbbb58c8ae4f70a2a503e2d5fc/raw/creds.json

# !wget https://gist.github.com/Vs8th/39c5deed0f5539d781f00328f7fd4fe0/raw/result.txt
# Out:
# --2026-05-19 13:19:03--  https://gist.github.com/Vs8th/d0bd4bdbbb58c8ae4f70a2a503e2d5fc/raw/creds.json
# Resolving gist.github.com (gist.github.com)... 140.82.113.3
# Connecting to gist.github.com (gist.github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/d0bd4bdbbb58c8ae4f70a2a503e2d5fc/raw/creds.json [following]
# --2026-05-19 13:19:03--  https://gist.githubusercontent.com/Vs8th/d0bd4bdbbb58c8ae4f70a2a503e2d5fc/raw/creds.json
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2358 (2.3K) [text/plain]
# Saving to: ‘creds.json’
#
# creds.json          100%[===================>]   2.30K  --.-KB/s    in 0s
#
# 2026-05-19 13:19:03 (20.0 MB/s) - ‘creds.json’ saved [2358/2358]
#
# --2026-05-19 13:19:03--  https://gist.github.com/Vs8th/39c5deed0f5539d781f00328f7fd4fe0/raw/result.txt
# Resolving gist.github.com (gist.github.com)... 140.82.113.3
# Connecting to gist.github.com (gist.github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://gist.githubusercontent.com/Vs8th/39c5deed0f5539d781f00328f7fd4fe0/raw/result.txt [following]
# --2026-05-19 13:19:03--  https://gist.githubusercontent.com/Vs8th/39c5deed0f5539d781f00328f7fd4fe0/raw/result.txt
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 198 [text/plain]
# Saving to: ‘result.txt’
#
# result.txt          100%[===================>]     198  --.-KB/s    in 0s
#
# 2026-05-19 13:19:04 (9.17 MB/s) - ‘result.txt’ saved [198/198]

# %%
# Указываем необходимые права доступа к таблицам
scope = ['https://www.googleapis.com/auth/spreadsheets.readonly',
         'https://www.googleapis.com/auth/drive']

# Загружаем ключи аутентификации из файла json
creds = ServiceAccountCredentials.from_json_keyfile_name('creds.json', scope)

# Авторизуемся в Google Sheets API
client = gspread.authorize(creds)

# %%
sheet1 = client.open("Installments").worksheet("Лист1")
sheet1_data = sheet1.get_all_records()
sheet2 = client.open("Installments").worksheet("Лист2")
sheet2_data = sheet2.get_all_records()
sheet3 = client.open("Installments").worksheet("Лист3")
sheet3_data = sheet3.get_all_records()

# %%
installist = []
for x in sheet1_data:
  if x['installment'] == 'Y':
    installist.append(x)

# %%
installist

# %%
for x in installist:
  for y in sheet2_data:
    if x['student_id'] == y['student_id']:
      x.update(y)

# %%
for x in installist:
  for y in sheet3_data:
    if x['student_id'] == y['student_id']:
      x.update(y)

# %%
installist
# Out:
# [{'student_id': 1,
#   'student_name': 'Смирнова И.И.',
#   'installment': 'Y',
#   'last_payment_date': '20.09.2022',
#   'expected_payment_date': '19.03.2023',
#   'already_payed_amount': 122373,
#   'left_to_pay': 277627,
#   'one-time_payment': 133333,
#   'installment_amount': 400000},
#  {'student_id': 2,
#   'student_name': 'Кузнецова К.А.',
#   'installment': 'Y',
#   'last_payment_date': '09.08.2022',
#   'expected_payment_date': '05.02.2023',
#   'already_payed_amount': 325610,
#   'left_to_pay': 474390,
#   'one-time_payment': 266666,
#   'installment_amount': 800000},
#  {'student_id': 3,
#   'student_name': 'Петров К.А.',
#   'installment': 'Y',
#   'last_payment_date': '15.02.2022',
#   'expected_payment_date': '14.08.2022',
#   'already_payed_amount': 51843,
#   'left_to_pay': 148157,
#   'one-time_payment': 33333,
#   'installment_amount': 200000},
#  {'student_id': 4,
#   'student_name': 'Смирнова А.А.',
#   'installment': 'Y',
#   'last_payment_date': '22.12.2022',
#   'expected_payment_date': '20.06.2023',
#   'already_payed_amount': 19656,
#   'left_to_pay': 480344,
#   'one-time_payment': 41666,
#   'installment_amount': 500000},
#  {'student_id': 6,
#   'student_name': 'Иванов А.А.',
#   'installment': 'Y',
#   'last_payment_date': '29.07.2022',
#   'expected_payment_date': '25.01.2023',
#   'already_payed_amount': 18723,
#   'left_to_pay': 581277,
#   'one-time_payment': 100000,
#   'installment_amount': 600000},
#  {'student_id': 9,
#   'student_name': 'Иванов М.А.',
#   'installment': 'Y',
#   'last_payment_date': '20.12.2022',
#   'expected_payment_date': '18.06.2023',
#   'already_payed_amount': 75189,
#   'left_to_pay': 224811,
#   'one-time_payment': 50000,
#   'installment_amount': 300000},
#  {'student_id': 10,
#   'student_name': 'Иванов П.П.',
#   'installment': 'Y',
#   'last_payment_date': '23.06.2022',
#   'expected_payment_date': '20.12.2022',
#   'already_payed_amount': 52263,
#   'left_to_pay': 647737,
#   'one-time_payment': 116666,
#   'installment_amount': 700000},
#  {'student_id': 12,
#   'student_name': 'Петров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '11.08.2022',
#   'expected_payment_date': '07.02.2023',
#   'already_payed_amount': 174708,
#   'left_to_pay': 525292,
#   'one-time_payment': 116666,
#   'installment_amount': 700000},
#  {'student_id': 13,
#   'student_name': 'Петров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '27.05.2022',
#   'expected_payment_date': '23.11.2022',
#   'already_payed_amount': 20428,
#   'left_to_pay': 79572,
#   'one-time_payment': 16666,
#   'installment_amount': 100000},
#  {'student_id': 14,
#   'student_name': 'Иванов Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '30.05.2022',
#   'expected_payment_date': '26.11.2022',
#   'already_payed_amount': 71353,
#   'left_to_pay': 428647,
#   'one-time_payment': 41666,
#   'installment_amount': 500000},
#  {'student_id': 15,
#   'student_name': 'Николаева Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '07.06.2022',
#   'expected_payment_date': '04.12.2022',
#   'already_payed_amount': 96016,
#   'left_to_pay': 503984,
#   'one-time_payment': 100000,
#   'installment_amount': 600000},
#  {'student_id': 18,
#   'student_name': 'Смирнова Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '17.07.2022',
#   'expected_payment_date': '13.01.2023',
#   'already_payed_amount': 209083,
#   'left_to_pay': 490917,
#   'one-time_payment': 233333,
#   'installment_amount': 700000},
#  {'student_id': 20,
#   'student_name': 'Иванов К.А.',
#   'installment': 'Y',
#   'last_payment_date': '08.09.2022',
#   'expected_payment_date': '07.03.2023',
#   'already_payed_amount': 2549,
#   'left_to_pay': 197451,
#   'one-time_payment': 16666,
#   'installment_amount': 200000},
#  {'student_id': 21,
#   'student_name': 'Николаева М.А.',
#   'installment': 'Y',
#   'last_payment_date': '02.03.2022',
#   'expected_payment_date': '29.08.2022',
#   'already_payed_amount': 937,
#   'left_to_pay': 199063,
#   'one-time_payment': 16666,
#   'installment_amount': 200000},
#  {'student_id': 22,
#   'student_name': 'Кузнецова А.А.',
#   'installment': 'Y',
#   'last_payment_date': '25.01.2022',
#   'expected_payment_date': '24.07.2022',
#   'already_payed_amount': 24865,
#   'left_to_pay': 175135,
#   'one-time_payment': 66666,
#   'installment_amount': 200000},
#  {'student_id': 23,
#   'student_name': 'Иванов А.А.',
#   'installment': 'Y',
#   'last_payment_date': '26.05.2022',
#   'expected_payment_date': '22.11.2022',
#   'already_payed_amount': 15986,
#   'left_to_pay': 284014,
#   'one-time_payment': 25000,
#   'installment_amount': 300000},
#  {'student_id': 25,
#   'student_name': 'Петров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '02.02.2022',
#   'expected_payment_date': '01.08.2022',
#   'already_payed_amount': 52840,
#   'left_to_pay': 747160,
#   'one-time_payment': 66666,
#   'installment_amount': 800000},
#  {'student_id': 28,
#   'student_name': 'Кузнецова К.А.',
#   'installment': 'Y',
#   'last_payment_date': '20.07.2022',
#   'expected_payment_date': '16.01.2023',
#   'already_payed_amount': 58896,
#   'left_to_pay': 741104,
#   'one-time_payment': 133333,
#   'installment_amount': 800000},
#  {'student_id': 29,
#   'student_name': 'Иванов М.А.',
#   'installment': 'Y',
#   'last_payment_date': '26.10.2022',
#   'expected_payment_date': '24.04.2023',
#   'already_payed_amount': 109689,
#   'left_to_pay': 890311,
#   'one-time_payment': 166666,
#   'installment_amount': 1000000},
#  {'student_id': 30,
#   'student_name': 'Кузнецова Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '07.01.2022',
#   'expected_payment_date': '06.07.2022',
#   'already_payed_amount': 64739,
#   'left_to_pay': 335261,
#   'one-time_payment': 33333,
#   'installment_amount': 400000},
#  {'student_id': 34,
#   'student_name': 'Сидоров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '05.03.2022',
#   'expected_payment_date': '01.09.2022',
#   'already_payed_amount': 131282,
#   'left_to_pay': 868718,
#   'one-time_payment': 83333,
#   'installment_amount': 1000000},
#  {'student_id': 36,
#   'student_name': 'Петров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '25.05.2022',
#   'expected_payment_date': '21.11.2022',
#   'already_payed_amount': 4771,
#   'left_to_pay': 95229,
#   'one-time_payment': 16666,
#   'installment_amount': 100000},
#  {'student_id': 43,
#   'student_name': 'Кузнецова И.И.',
#   'installment': 'Y',
#   'last_payment_date': '25.03.2022',
#   'expected_payment_date': '21.09.2022',
#   'already_payed_amount': 273690,
#   'left_to_pay': 426310,
#   'one-time_payment': 233333,
#   'installment_amount': 700000},
#  {'student_id': 44,
#   'student_name': 'Иванов А.А.',
#   'installment': 'Y',
#   'last_payment_date': '30.03.2022',
#   'expected_payment_date': '26.09.2022',
#   'already_payed_amount': 529302,
#   'left_to_pay': 270698,
#   'one-time_payment': 266666,
#   'installment_amount': 800000},
#  {'student_id': 45,
#   'student_name': 'Сидоров К.А.',
#   'installment': 'Y',
#   'last_payment_date': '17.07.2022',
#   'expected_payment_date': '13.01.2023',
#   'already_payed_amount': 23246,
#   'left_to_pay': 776754,
#   'one-time_payment': 266666,
#   'installment_amount': 800000},
#  {'student_id': 46,
#   'student_name': 'Иванов М.А.',
#   'installment': 'Y',
#   'last_payment_date': '16.09.2022',
#   'expected_payment_date': '15.03.2023',
#   'already_payed_amount': 69964,
#   'left_to_pay': 230036,
#   'one-time_payment': 100000,
#   'installment_amount': 300000},
#  {'student_id': 49,
#   'student_name': 'Николаева К.А.',
#   'installment': 'Y',
#   'last_payment_date': '14.11.2022',
#   'expected_payment_date': '13.05.2023',
#   'already_payed_amount': 45416,
#   'left_to_pay': 454584,
#   'one-time_payment': 83333,
#   'installment_amount': 500000},
#  {'student_id': 50,
#   'student_name': 'Петров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '21.10.2022',
#   'expected_payment_date': '19.04.2023',
#   'already_payed_amount': 329859,
#   'left_to_pay': 170141,
#   'one-time_payment': 166666,
#   'installment_amount': 500000},
#  {'student_id': 51,
#   'student_name': 'Смирнова И.И.',
#   'installment': 'Y',
#   'last_payment_date': '08.06.2022',
#   'expected_payment_date': '05.12.2022',
#   'already_payed_amount': 242500,
#   'left_to_pay': 357500,
#   'one-time_payment': 200000,
#   'installment_amount': 600000},
#  {'student_id': 53,
#   'student_name': 'Сидоров М.А.',
#   'installment': 'Y',
#   'last_payment_date': '07.03.2022',
#   'expected_payment_date': '03.09.2022',
#   'already_payed_amount': 298193,
#   'left_to_pay': 201807,
#   'one-time_payment': 166666,
#   'installment_amount': 500000},
#  {'student_id': 54,
#   'student_name': 'Сидоров К.А.',
#   'installment': 'Y',
#   'last_payment_date': '29.10.2022',
#   'expected_payment_date': '27.04.2023',
#   'already_payed_amount': 14437,
#   'left_to_pay': 485563,
#   'one-time_payment': 41666,
#   'installment_amount': 500000},
#  {'student_id': 55,
#   'student_name': 'Сидоров Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '28.08.2022',
#   'expected_payment_date': '24.02.2023',
#   'already_payed_amount': 29140,
#   'left_to_pay': 70860,
#   'one-time_payment': 33333,
#   'installment_amount': 100000},
#  {'student_id': 59,
#   'student_name': 'Смирнова К.А.',
#   'installment': 'Y',
#   'last_payment_date': '16.09.2022',
#   'expected_payment_date': '15.03.2023',
#   'already_payed_amount': 350570,
#   'left_to_pay': 649430,
#   'one-time_payment': 333333,
#   'installment_amount': 1000000},
#  {'student_id': 61,
#   'student_name': 'Иванов Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '07.02.2022',
#   'expected_payment_date': '06.08.2022',
#   'already_payed_amount': 83201,
#   'left_to_pay': 216799,
#   'one-time_payment': 50000,
#   'installment_amount': 300000},
#  {'student_id': 63,
#   'student_name': 'Кузнецова А.А.',
#   'installment': 'Y',
#   'last_payment_date': '06.10.2022',
#   'expected_payment_date': '04.04.2023',
#   'already_payed_amount': 60645,
#   'left_to_pay': 339355,
#   'one-time_payment': 66666,
#   'installment_amount': 400000},
#  {'student_id': 68,
#   'student_name': 'Иванов К.А.',
#   'installment': 'Y',
#   'last_payment_date': '20.06.2022',
#   'expected_payment_date': '17.12.2022',
#   'already_payed_amount': 49021,
#   'left_to_pay': 250979,
#   'one-time_payment': 100000,
#   'installment_amount': 300000},
#  {'student_id': 69,
#   'student_name': 'Николаева К.А.',
#   'installment': 'Y',
#   'last_payment_date': '17.03.2022',
#   'expected_payment_date': '13.09.2022',
#   'already_payed_amount': 68222,
#   'left_to_pay': 431778,
#   'one-time_payment': 166666,
#   'installment_amount': 500000},
#  {'student_id': 70,
#   'student_name': 'Николаева А.А.',
#   'installment': 'Y',
#   'last_payment_date': '13.12.2022',
#   'expected_payment_date': '11.06.2023',
#   'already_payed_amount': 54096,
#   'left_to_pay': 645904,
#   'one-time_payment': 116666,
#   'installment_amount': 700000},
#  {'student_id': 73,
#   'student_name': 'Николаева А.А.',
#   'installment': 'Y',
#   'last_payment_date': '25.08.2022',
#   'expected_payment_date': '21.02.2023',
#   'already_payed_amount': 6086,
#   'left_to_pay': 993914,
#   'one-time_payment': 83333,
#   'installment_amount': 1000000},
#  {'student_id': 78,
#   'student_name': 'Кузнецова А.А.',
#   'installment': 'Y',
#   'last_payment_date': '03.12.2022',
#   'expected_payment_date': '01.06.2023',
#   'already_payed_amount': 212979,
#   'left_to_pay': 487021,
#   'one-time_payment': 116666,
#   'installment_amount': 700000},
#  {'student_id': 80,
#   'student_name': 'Сидоров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '09.01.2022',
#   'expected_payment_date': '08.07.2022',
#   'already_payed_amount': 25419,
#   'left_to_pay': 374581,
#   'one-time_payment': 66666,
#   'installment_amount': 400000},
#  {'student_id': 81,
#   'student_name': 'Николаева Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '04.04.2022',
#   'expected_payment_date': '01.10.2022',
#   'already_payed_amount': 9164,
#   'left_to_pay': 790836,
#   'one-time_payment': 66666,
#   'installment_amount': 800000},
#  {'student_id': 82,
#   'student_name': 'Иванов П.П.',
#   'installment': 'Y',
#   'last_payment_date': '19.09.2022',
#   'expected_payment_date': '18.03.2023',
#   'already_payed_amount': 80885,
#   'left_to_pay': 219115,
#   'one-time_payment': 50000,
#   'installment_amount': 300000},
#  {'student_id': 83,
#   'student_name': 'Иванов Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '18.10.2022',
#   'expected_payment_date': '16.04.2023',
#   'already_payed_amount': 210586,
#   'left_to_pay': 489414,
#   'one-time_payment': 116666,
#   'installment_amount': 700000},
#  {'student_id': 84,
#   'student_name': 'Смирнова П.П.',
#   'installment': 'Y',
#   'last_payment_date': '23.08.2022',
#   'expected_payment_date': '19.02.2023',
#   'already_payed_amount': 223050,
#   'left_to_pay': 776950,
#   'one-time_payment': 166666,
#   'installment_amount': 1000000},
#  {'student_id': 86,
#   'student_name': 'Сидоров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '13.07.2022',
#   'expected_payment_date': '09.01.2023',
#   'already_payed_amount': 162200,
#   'left_to_pay': 137800,
#   'one-time_payment': 100000,
#   'installment_amount': 300000},
#  {'student_id': 90,
#   'student_name': 'Смирнова М.А.',
#   'installment': 'Y',
#   'last_payment_date': '19.04.2022',
#   'expected_payment_date': '16.10.2022',
#   'already_payed_amount': 81258,
#   'left_to_pay': 818742,
#   'one-time_payment': 75000,
#   'installment_amount': 900000},
#  {'student_id': 92,
#   'student_name': 'Сидоров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '23.06.2022',
#   'expected_payment_date': '20.12.2022',
#   'already_payed_amount': 25280,
#   'left_to_pay': 74720,
#   'one-time_payment': 16666,
#   'installment_amount': 100000},
#  {'student_id': 93,
#   'student_name': 'Сидоров К.А.',
#   'installment': 'Y',
#   'last_payment_date': '01.06.2022',
#   'expected_payment_date': '28.11.2022',
#   'already_payed_amount': 1959,
#   'left_to_pay': 598041,
#   'one-time_payment': 100000,
#   'installment_amount': 600000},
#  {'student_id': 95,
#   'student_name': 'Николаева К.А.',
#   'installment': 'Y',
#   'last_payment_date': '10.04.2022',
#   'expected_payment_date': '07.10.2022',
#   'already_payed_amount': 397132,
#   'left_to_pay': 202868,
#   'one-time_payment': 200000,
#   'installment_amount': 600000},
#  {'student_id': 96,
#   'student_name': 'Петров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '13.12.2022',
#   'expected_payment_date': '11.06.2023',
#   'already_payed_amount': 25618,
#   'left_to_pay': 474382,
#   'one-time_payment': 41666,
#   'installment_amount': 500000},
#  {'student_id': 97,
#   'student_name': 'Сидоров Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '08.02.2022',
#   'expected_payment_date': '07.08.2022',
#   'already_payed_amount': 181503,
#   'left_to_pay': 518497,
#   'one-time_payment': 116666,
#   'installment_amount': 700000},
#  {'student_id': 100,
#   'student_name': 'Николаева П.П.',
#   'installment': 'Y',
#   'last_payment_date': '22.09.2022',
#   'expected_payment_date': '21.03.2023',
#   'already_payed_amount': 265188,
#   'left_to_pay': 134812,
#   'one-time_payment': 133333,
#   'installment_amount': 400000},
#  {'student_id': 103,
#   'student_name': 'Смирнова Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '27.06.2022',
#   'expected_payment_date': '24.12.2022',
#   'already_payed_amount': 17128,
#   'left_to_pay': 282872,
#   'one-time_payment': 100000,
#   'installment_amount': 300000},
#  {'student_id': 105,
#   'student_name': 'Сидоров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '11.02.2022',
#   'expected_payment_date': '10.08.2022',
#   'already_payed_amount': 370344,
#   'left_to_pay': 629656,
#   'one-time_payment': 333333,
#   'installment_amount': 1000000},
#  {'student_id': 107,
#   'student_name': 'Николаева К.А.',
#   'installment': 'Y',
#   'last_payment_date': '18.10.2022',
#   'expected_payment_date': '16.04.2023',
#   'already_payed_amount': 144703,
#   'left_to_pay': 355297,
#   'one-time_payment': 83333,
#   'installment_amount': 500000},
#  {'student_id': 108,
#   'student_name': 'Николаева А.А.',
#   'installment': 'Y',
#   'last_payment_date': '12.09.2022',
#   'expected_payment_date': '11.03.2023',
#   'already_payed_amount': 480724,
#   'left_to_pay': 319276,
#   'one-time_payment': 266666,
#   'installment_amount': 800000},
#  {'student_id': 111,
#   'student_name': 'Смирнова Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '24.10.2022',
#   'expected_payment_date': '22.04.2023',
#   'already_payed_amount': 167625,
#   'left_to_pay': 232375,
#   'one-time_payment': 133333,
#   'installment_amount': 400000},
#  {'student_id': 115,
#   'student_name': 'Николаева К.А.',
#   'installment': 'Y',
#   'last_payment_date': '10.12.2022',
#   'expected_payment_date': '08.06.2023',
#   'already_payed_amount': 13946,
#   'left_to_pay': 686054,
#   'one-time_payment': 116666,
#   'installment_amount': 700000},
#  {'student_id': 116,
#   'student_name': 'Сидоров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '02.03.2022',
#   'expected_payment_date': '29.08.2022',
#   'already_payed_amount': 32955,
#   'left_to_pay': 667045,
#   'one-time_payment': 116666,
#   'installment_amount': 700000},
#  {'student_id': 117,
#   'student_name': 'Иванов Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '22.08.2022',
#   'expected_payment_date': '18.02.2023',
#   'already_payed_amount': 49072,
#   'left_to_pay': 250928,
#   'one-time_payment': 25000,
#   'installment_amount': 300000},
#  {'student_id': 118,
#   'student_name': 'Смирнова П.П.',
#   'installment': 'Y',
#   'last_payment_date': '03.05.2022',
#   'expected_payment_date': '30.10.2022',
#   'already_payed_amount': 184702,
#   'left_to_pay': 415298,
#   'one-time_payment': 200000,
#   'installment_amount': 600000},
#  {'student_id': 119,
#   'student_name': 'Иванов М.А.',
#   'installment': 'Y',
#   'last_payment_date': '18.08.2022',
#   'expected_payment_date': '14.02.2023',
#   'already_payed_amount': 12976,
#   'left_to_pay': 787024,
#   'one-time_payment': 66666,
#   'installment_amount': 800000},
#  {'student_id': 120,
#   'student_name': 'Смирнова А.А.',
#   'installment': 'Y',
#   'last_payment_date': '31.12.2022',
#   'expected_payment_date': '29.06.2023',
#   'already_payed_amount': 18716,
#   'left_to_pay': 481284,
#   'one-time_payment': 83333,
#   'installment_amount': 500000},
#  {'student_id': 122,
#   'student_name': 'Иванов К.А.',
#   'installment': 'Y',
#   'last_payment_date': '22.05.2022',
#   'expected_payment_date': '18.11.2022',
#   'already_payed_amount': 53055,
#   'left_to_pay': 446945,
#   'one-time_payment': 41666,
#   'installment_amount': 500000},
#  {'student_id': 123,
#   'student_name': 'Николаева Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '15.05.2022',
#   'expected_payment_date': '11.11.2022',
#   'already_payed_amount': 38333,
#   'left_to_pay': 861667,
#   'one-time_payment': 150000,
#   'installment_amount': 900000},
#  {'student_id': 124,
#   'student_name': 'Сидоров Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '05.10.2022',
#   'expected_payment_date': '03.04.2023',
#   'already_payed_amount': 52046,
#   'left_to_pay': 647954,
#   'one-time_payment': 58333,
#   'installment_amount': 700000},
#  {'student_id': 128,
#   'student_name': 'Николаева Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '04.10.2022',
#   'expected_payment_date': '02.04.2023',
#   'already_payed_amount': 87890,
#   'left_to_pay': 812110,
#   'one-time_payment': 150000,
#   'installment_amount': 900000},
#  {'student_id': 130,
#   'student_name': 'Петров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '09.02.2022',
#   'expected_payment_date': '08.08.2022',
#   'already_payed_amount': 7425,
#   'left_to_pay': 392575,
#   'one-time_payment': 66666,
#   'installment_amount': 400000},
#  {'student_id': 133,
#   'student_name': 'Кузнецова Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '30.05.2022',
#   'expected_payment_date': '26.11.2022',
#   'already_payed_amount': 6596,
#   'left_to_pay': 693404,
#   'one-time_payment': 58333,
#   'installment_amount': 700000},
#  {'student_id': 137,
#   'student_name': 'Петров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '03.09.2022',
#   'expected_payment_date': '02.03.2023',
#   'already_payed_amount': 14058,
#   'left_to_pay': 85942,
#   'one-time_payment': 8333,
#   'installment_amount': 100000},
#  {'student_id': 138,
#   'student_name': 'Петров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '22.04.2022',
#   'expected_payment_date': '19.10.2022',
#   'already_payed_amount': 72406,
#   'left_to_pay': 327594,
#   'one-time_payment': 66666,
#   'installment_amount': 400000},
#  {'student_id': 140,
#   'student_name': 'Сидоров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '21.05.2022',
#   'expected_payment_date': '17.11.2022',
#   'already_payed_amount': 176525,
#   'left_to_pay': 123475,
#   'one-time_payment': 100000,
#   'installment_amount': 300000},
#  {'student_id': 141,
#   'student_name': 'Сидоров Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '01.02.2022',
#   'expected_payment_date': '31.07.2022',
#   'already_payed_amount': 25508,
#   'left_to_pay': 374492,
#   'one-time_payment': 133333,
#   'installment_amount': 400000},
#  {'student_id': 146,
#   'student_name': 'Иванов К.А.',
#   'installment': 'Y',
#   'last_payment_date': '24.11.2022',
#   'expected_payment_date': '23.05.2023',
#   'already_payed_amount': 22651,
#   'left_to_pay': 977349,
#   'one-time_payment': 83333,
#   'installment_amount': 1000000},
#  {'student_id': 147,
#   'student_name': 'Петров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '18.11.2022',
#   'expected_payment_date': '17.05.2023',
#   'already_payed_amount': 90924,
#   'left_to_pay': 309076,
#   'one-time_payment': 66666,
#   'installment_amount': 400000},
#  {'student_id': 152,
#   'student_name': 'Иванов А.А.',
#   'installment': 'Y',
#   'last_payment_date': '04.03.2022',
#   'expected_payment_date': '31.08.2022',
#   'already_payed_amount': 20061,
#   'left_to_pay': 779939,
#   'one-time_payment': 66666,
#   'installment_amount': 800000},
#  {'student_id': 156,
#   'student_name': 'Сидоров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '25.04.2022',
#   'expected_payment_date': '22.10.2022',
#   'already_payed_amount': 94867,
#   'left_to_pay': 205133,
#   'one-time_payment': 50000,
#   'installment_amount': 300000},
#  {'student_id': 157,
#   'student_name': 'Сидоров Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '26.10.2022',
#   'expected_payment_date': '24.04.2023',
#   'already_payed_amount': 96793,
#   'left_to_pay': 103207,
#   'one-time_payment': 66666,
#   'installment_amount': 200000},
#  {'student_id': 161,
#   'student_name': 'Николаева И.И.',
#   'installment': 'Y',
#   'last_payment_date': '16.10.2022',
#   'expected_payment_date': '14.04.2023',
#   'already_payed_amount': 305850,
#   'left_to_pay': 594150,
#   'one-time_payment': 300000,
#   'installment_amount': 900000},
#  {'student_id': 162,
#   'student_name': 'Смирнова М.А.',
#   'installment': 'Y',
#   'last_payment_date': '08.08.2022',
#   'expected_payment_date': '04.02.2023',
#   'already_payed_amount': 13255,
#   'left_to_pay': 886745,
#   'one-time_payment': 75000,
#   'installment_amount': 900000},
#  {'student_id': 164,
#   'student_name': 'Сидоров М.А.',
#   'installment': 'Y',
#   'last_payment_date': '03.09.2022',
#   'expected_payment_date': '02.03.2023',
#   'already_payed_amount': 31212,
#   'left_to_pay': 168788,
#   'one-time_payment': 16666,
#   'installment_amount': 200000},
#  {'student_id': 168,
#   'student_name': 'Смирнова И.И.',
#   'installment': 'Y',
#   'last_payment_date': '21.12.2022',
#   'expected_payment_date': '19.06.2023',
#   'already_payed_amount': 50277,
#   'left_to_pay': 649723,
#   'one-time_payment': 58333,
#   'installment_amount': 700000},
#  {'student_id': 169,
#   'student_name': 'Сидоров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '20.04.2022',
#   'expected_payment_date': '17.10.2022',
#   'already_payed_amount': 111061,
#   'left_to_pay': 288939,
#   'one-time_payment': 66666,
#   'installment_amount': 400000},
#  {'student_id': 170,
#   'student_name': 'Смирнова П.П.',
#   'installment': 'Y',
#   'last_payment_date': '26.09.2022',
#   'expected_payment_date': '25.03.2023',
#   'already_payed_amount': 54587,
#   'left_to_pay': 45413,
#   'one-time_payment': 33333,
#   'installment_amount': 100000},
#  {'student_id': 174,
#   'student_name': 'Смирнова П.П.',
#   'installment': 'Y',
#   'last_payment_date': '03.05.2022',
#   'expected_payment_date': '30.10.2022',
#   'already_payed_amount': 385461,
#   'left_to_pay': 414539,
#   'one-time_payment': 266666,
#   'installment_amount': 800000},
#  {'student_id': 176,
#   'student_name': 'Сидоров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '18.10.2022',
#   'expected_payment_date': '16.04.2023',
#   'already_payed_amount': 23132,
#   'left_to_pay': 576868,
#   'one-time_payment': 200000,
#   'installment_amount': 600000},
#  {'student_id': 177,
#   'student_name': 'Иванов П.П.',
#   'installment': 'Y',
#   'last_payment_date': '21.02.2022',
#   'expected_payment_date': '20.08.2022',
#   'already_payed_amount': 100807,
#   'left_to_pay': 399193,
#   'one-time_payment': 83333,
#   'installment_amount': 500000},
#  {'student_id': 178,
#   'student_name': 'Петров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '18.03.2022',
#   'expected_payment_date': '14.09.2022',
#   'already_payed_amount': 139155,
#   'left_to_pay': 560845,
#   'one-time_payment': 116666,
#   'installment_amount': 700000},
#  {'student_id': 179,
#   'student_name': 'Петров М.А.',
#   'installment': 'Y',
#   'last_payment_date': '02.05.2022',
#   'expected_payment_date': '29.10.2022',
#   'already_payed_amount': 37651,
#   'left_to_pay': 62349,
#   'one-time_payment': 33333,
#   'installment_amount': 100000},
#  {'student_id': 180,
#   'student_name': 'Сидоров К.А.',
#   'installment': 'Y',
#   'last_payment_date': '12.01.2022',
#   'expected_payment_date': '11.07.2022',
#   'already_payed_amount': 484016,
#   'left_to_pay': 315984,
#   'one-time_payment': 266666,
#   'installment_amount': 800000},
#  {'student_id': 181,
#   'student_name': 'Сидоров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '12.06.2022',
#   'expected_payment_date': '09.12.2022',
#   'already_payed_amount': 146386,
#   'left_to_pay': 453614,
#   'one-time_payment': 100000,
#   'installment_amount': 600000},
#  {'student_id': 182,
#   'student_name': 'Сидоров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '08.04.2022',
#   'expected_payment_date': '05.10.2022',
#   'already_payed_amount': 48179,
#   'left_to_pay': 551821,
#   'one-time_payment': 100000,
#   'installment_amount': 600000},
#  {'student_id': 183,
#   'student_name': 'Кузнецова М.А.',
#   'installment': 'Y',
#   'last_payment_date': '24.07.2022',
#   'expected_payment_date': '20.01.2023',
#   'already_payed_amount': 227257,
#   'left_to_pay': 472743,
#   'one-time_payment': 116666,
#   'installment_amount': 700000},
#  {'student_id': 188,
#   'student_name': 'Иванов М.А.',
#   'installment': 'Y',
#   'last_payment_date': '29.06.2022',
#   'expected_payment_date': '26.12.2022',
#   'already_payed_amount': 152108,
#   'left_to_pay': 347892,
#   'one-time_payment': 83333,
#   'installment_amount': 500000},
#  {'student_id': 189,
#   'student_name': 'Петров К.А.',
#   'installment': 'Y',
#   'last_payment_date': '21.12.2022',
#   'expected_payment_date': '19.06.2023',
#   'already_payed_amount': 133707,
#   'left_to_pay': 766293,
#   'one-time_payment': 75000,
#   'installment_amount': 900000},
#  {'student_id': 190,
#   'student_name': 'Петров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '08.09.2022',
#   'expected_payment_date': '07.03.2023',
#   'already_payed_amount': 524,
#   'left_to_pay': 899476,
#   'one-time_payment': 75000,
#   'installment_amount': 900000},
#  {'student_id': 194,
#   'student_name': 'Иванов П.П.',
#   'installment': 'Y',
#   'last_payment_date': '24.04.2022',
#   'expected_payment_date': '21.10.2022',
#   'already_payed_amount': 27569,
#   'left_to_pay': 172431,
#   'one-time_payment': 16666,
#   'installment_amount': 200000},
#  {'student_id': 195,
#   'student_name': 'Кузнецова М.А.',
#   'installment': 'Y',
#   'last_payment_date': '01.05.2022',
#   'expected_payment_date': '28.10.2022',
#   'already_payed_amount': 96450,
#   'left_to_pay': 703550,
#   'one-time_payment': 133333,
#   'installment_amount': 800000},
#  {'student_id': 196,
#   'student_name': 'Сидоров М.А.',
#   'installment': 'Y',
#   'last_payment_date': '09.01.2022',
#   'expected_payment_date': '08.07.2022',
#   'already_payed_amount': 27496,
#   'left_to_pay': 72504,
#   'one-time_payment': 33333,
#   'installment_amount': 100000},
#  {'student_id': 197,
#   'student_name': 'Кузнецова Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '10.03.2022',
#   'expected_payment_date': '06.09.2022',
#   'already_payed_amount': 26257,
#   'left_to_pay': 173743,
#   'one-time_payment': 66666,
#   'installment_amount': 200000},
#  {'student_id': 198,
#   'student_name': 'Смирнова К.А.',
#   'installment': 'Y',
#   'last_payment_date': '13.04.2022',
#   'expected_payment_date': '10.10.2022',
#   'already_payed_amount': 11785,
#   'left_to_pay': 488215,
#   'one-time_payment': 83333,
#   'installment_amount': 500000},
#  {'student_id': 199,
#   'student_name': 'Кузнецова П.П.',
#   'installment': 'Y',
#   'last_payment_date': '14.06.2022',
#   'expected_payment_date': '11.12.2022',
#   'already_payed_amount': 128056,
#   'left_to_pay': 171944,
#   'one-time_payment': 100000,
#   'installment_amount': 300000},
#  {'student_id': 204,
#   'student_name': 'Кузнецова К.А.',
#   'installment': 'Y',
#   'last_payment_date': '11.04.2022',
#   'expected_payment_date': '08.10.2022',
#   'already_payed_amount': 94552,
#   'left_to_pay': 605448,
#   'one-time_payment': 58333,
#   'installment_amount': 700000},
#  {'student_id': 205,
#   'student_name': 'Николаева К.А.',
#   'installment': 'Y',
#   'last_payment_date': '30.08.2022',
#   'expected_payment_date': '26.02.2023',
#   'already_payed_amount': 115821,
#   'left_to_pay': 784179,
#   'one-time_payment': 75000,
#   'installment_amount': 900000},
#  {'student_id': 206,
#   'student_name': 'Петров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '22.11.2022',
#   'expected_payment_date': '21.05.2023',
#   'already_payed_amount': 104341,
#   'left_to_pay': 695659,
#   'one-time_payment': 133333,
#   'installment_amount': 800000},
#  {'student_id': 207,
#   'student_name': 'Кузнецова К.А.',
#   'installment': 'Y',
#   'last_payment_date': '18.03.2022',
#   'expected_payment_date': '14.09.2022',
#   'already_payed_amount': 171849,
#   'left_to_pay': 428151,
#   'one-time_payment': 100000,
#   'installment_amount': 600000},
#  {'student_id': 209,
#   'student_name': 'Кузнецова И.И.',
#   'installment': 'Y',
#   'last_payment_date': '10.11.2022',
#   'expected_payment_date': '09.05.2023',
#   'already_payed_amount': 528195,
#   'left_to_pay': 271805,
#   'one-time_payment': 266666,
#   'installment_amount': 800000},
#  {'student_id': 210,
#   'student_name': 'Иванов П.П.',
#   'installment': 'Y',
#   'last_payment_date': '12.03.2022',
#   'expected_payment_date': '08.09.2022',
#   'already_payed_amount': 101799,
#   'left_to_pay': 598201,
#   'one-time_payment': 58333,
#   'installment_amount': 700000},
#  {'student_id': 212,
#   'student_name': 'Сидоров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '16.09.2022',
#   'expected_payment_date': '15.03.2023',
#   'already_payed_amount': 6646,
#   'left_to_pay': 593354,
#   'one-time_payment': 50000,
#   'installment_amount': 600000},
#  {'student_id': 213,
#   'student_name': 'Петров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '04.04.2022',
#   'expected_payment_date': '01.10.2022',
#   'already_payed_amount': 181364,
#   'left_to_pay': 318636,
#   'one-time_payment': 166666,
#   'installment_amount': 500000},
#  {'student_id': 215,
#   'student_name': 'Сидоров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '07.05.2022',
#   'expected_payment_date': '03.11.2022',
#   'already_payed_amount': 42511,
#   'left_to_pay': 157489,
#   'one-time_payment': 33333,
#   'installment_amount': 200000},
#  {'student_id': 216,
#   'student_name': 'Кузнецова П.П.',
#   'installment': 'Y',
#   'last_payment_date': '16.06.2022',
#   'expected_payment_date': '13.12.2022',
#   'already_payed_amount': 53555,
#   'left_to_pay': 546445,
#   'one-time_payment': 50000,
#   'installment_amount': 600000},
#  {'student_id': 218,
#   'student_name': 'Иванов К.А.',
#   'installment': 'Y',
#   'last_payment_date': '25.09.2022',
#   'expected_payment_date': '24.03.2023',
#   'already_payed_amount': 9517,
#   'left_to_pay': 990483,
#   'one-time_payment': 166666,
#   'installment_amount': 1000000},
#  {'student_id': 223,
#   'student_name': 'Иванов К.А.',
#   'installment': 'Y',
#   'last_payment_date': '13.01.2022',
#   'expected_payment_date': '12.07.2022',
#   'already_payed_amount': 327811,
#   'left_to_pay': 272189,
#   'one-time_payment': 200000,
#   'installment_amount': 600000},
#  {'student_id': 224,
#   'student_name': 'Петров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '27.01.2022',
#   'expected_payment_date': '26.07.2022',
#   'already_payed_amount': 10138,
#   'left_to_pay': 189862,
#   'one-time_payment': 66666,
#   'installment_amount': 200000},
#  {'student_id': 225,
#   'student_name': 'Петров К.А.',
#   'installment': 'Y',
#   'last_payment_date': '25.08.2022',
#   'expected_payment_date': '21.02.2023',
#   'already_payed_amount': 253694,
#   'left_to_pay': 346306,
#   'one-time_payment': 200000,
#   'installment_amount': 600000},
#  {'student_id': 226,
#   'student_name': 'Сидоров Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '28.06.2022',
#   'expected_payment_date': '25.12.2022',
#   'already_payed_amount': 49185,
#   'left_to_pay': 250815,
#   'one-time_payment': 25000,
#   'installment_amount': 300000},
#  {'student_id': 227,
#   'student_name': 'Николаева П.П.',
#   'installment': 'Y',
#   'last_payment_date': '21.01.2022',
#   'expected_payment_date': '20.07.2022',
#   'already_payed_amount': 81593,
#   'left_to_pay': 418407,
#   'one-time_payment': 166666,
#   'installment_amount': 500000},
#  {'student_id': 229,
#   'student_name': 'Петров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '26.06.2022',
#   'expected_payment_date': '23.12.2022',
#   'already_payed_amount': 2250,
#   'left_to_pay': 97750,
#   'one-time_payment': 33333,
#   'installment_amount': 100000},
#  {'student_id': 230,
#   'student_name': 'Петров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '07.05.2022',
#   'expected_payment_date': '03.11.2022',
#   'already_payed_amount': 182080,
#   'left_to_pay': 217920,
#   'one-time_payment': 133333,
#   'installment_amount': 400000},
#  {'student_id': 232,
#   'student_name': 'Иванов П.П.',
#   'installment': 'Y',
#   'last_payment_date': '22.04.2022',
#   'expected_payment_date': '19.10.2022',
#   'already_payed_amount': 35565,
#   'left_to_pay': 164435,
#   'one-time_payment': 33333,
#   'installment_amount': 200000},
#  {'student_id': 234,
#   'student_name': 'Кузнецова Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '19.02.2022',
#   'expected_payment_date': '18.08.2022',
#   'already_payed_amount': 47381,
#   'left_to_pay': 752619,
#   'one-time_payment': 66666,
#   'installment_amount': 800000},
#  {'student_id': 235,
#   'student_name': 'Смирнова М.А.',
#   'installment': 'Y',
#   'last_payment_date': '21.05.2022',
#   'expected_payment_date': '17.11.2022',
#   'already_payed_amount': 54648,
#   'left_to_pay': 245352,
#   'one-time_payment': 100000,
#   'installment_amount': 300000},
#  {'student_id': 237,
#   'student_name': 'Смирнова И.И.',
#   'installment': 'Y',
#   'last_payment_date': '17.07.2022',
#   'expected_payment_date': '13.01.2023',
#   'already_payed_amount': 68042,
#   'left_to_pay': 931958,
#   'one-time_payment': 83333,
#   'installment_amount': 1000000},
#  {'student_id': 239,
#   'student_name': 'Иванов И.И.',
#   'installment': 'Y',
#   'last_payment_date': '01.07.2022',
#   'expected_payment_date': '28.12.2022',
#   'already_payed_amount': 83854,
#   'left_to_pay': 416146,
#   'one-time_payment': 166666,
#   'installment_amount': 500000},
#  {'student_id': 240,
#   'student_name': 'Петров К.А.',
#   'installment': 'Y',
#   'last_payment_date': '03.10.2022',
#   'expected_payment_date': '01.04.2023',
#   'already_payed_amount': 226140,
#   'left_to_pay': 773860,
#   'one-time_payment': 333333,
#   'installment_amount': 1000000},
#  {'student_id': 241,
#   'student_name': 'Петров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '20.04.2022',
#   'expected_payment_date': '17.10.2022',
#   'already_payed_amount': 202478,
#   'left_to_pay': 497522,
#   'one-time_payment': 233333,
#   'installment_amount': 700000},
#  {'student_id': 242,
#   'student_name': 'Кузнецова И.И.',
#   'installment': 'Y',
#   'last_payment_date': '20.06.2022',
#   'expected_payment_date': '17.12.2022',
#   'already_payed_amount': 31203,
#   'left_to_pay': 168797,
#   'one-time_payment': 16666,
#   'installment_amount': 200000},
#  {'student_id': 246,
#   'student_name': 'Кузнецова П.П.',
#   'installment': 'Y',
#   'last_payment_date': '06.12.2022',
#   'expected_payment_date': '04.06.2023',
#   'already_payed_amount': 7646,
#   'left_to_pay': 292354,
#   'one-time_payment': 50000,
#   'installment_amount': 300000},
#  {'student_id': 251,
#   'student_name': 'Иванов И.И.',
#   'installment': 'Y',
#   'last_payment_date': '25.07.2022',
#   'expected_payment_date': '21.01.2023',
#   'already_payed_amount': 16316,
#   'left_to_pay': 83684,
#   'one-time_payment': 16666,
#   'installment_amount': 100000},
#  {'student_id': 252,
#   'student_name': 'Кузнецова М.А.',
#   'installment': 'Y',
#   'last_payment_date': '29.11.2022',
#   'expected_payment_date': '28.05.2023',
#   'already_payed_amount': 34851,
#   'left_to_pay': 65149,
#   'one-time_payment': 33333,
#   'installment_amount': 100000},
#  {'student_id': 254,
#   'student_name': 'Смирнова К.А.',
#   'installment': 'Y',
#   'last_payment_date': '25.07.2022',
#   'expected_payment_date': '21.01.2023',
#   'already_payed_amount': 31568,
#   'left_to_pay': 668432,
#   'one-time_payment': 233333,
#   'installment_amount': 700000},
#  {'student_id': 257,
#   'student_name': 'Петров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '14.09.2022',
#   'expected_payment_date': '13.03.2023',
#   'already_payed_amount': 24692,
#   'left_to_pay': 275308,
#   'one-time_payment': 25000,
#   'installment_amount': 300000},
#  {'student_id': 259,
#   'student_name': 'Иванов М.А.',
#   'installment': 'Y',
#   'last_payment_date': '22.05.2022',
#   'expected_payment_date': '18.11.2022',
#   'already_payed_amount': 64445,
#   'left_to_pay': 435555,
#   'one-time_payment': 41666,
#   'installment_amount': 500000},
#  {'student_id': 260,
#   'student_name': 'Кузнецова П.П.',
#   'installment': 'Y',
#   'last_payment_date': '12.11.2022',
#   'expected_payment_date': '11.05.2023',
#   'already_payed_amount': 44883,
#   'left_to_pay': 855117,
#   'one-time_payment': 150000,
#   'installment_amount': 900000},
#  {'student_id': 266,
#   'student_name': 'Иванов А.А.',
#   'installment': 'Y',
#   'last_payment_date': '05.11.2022',
#   'expected_payment_date': '04.05.2023',
#   'already_payed_amount': 555942,
#   'left_to_pay': 444058,
#   'one-time_payment': 333333,
#   'installment_amount': 1000000},
#  {'student_id': 267,
#   'student_name': 'Сидоров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '18.01.2022',
#   'expected_payment_date': '17.07.2022',
#   'already_payed_amount': 371565,
#   'left_to_pay': 528435,
#   'one-time_payment': 300000,
#   'installment_amount': 900000},
#  {'student_id': 272,
#   'student_name': 'Иванов М.А.',
#   'installment': 'Y',
#   'last_payment_date': '18.03.2022',
#   'expected_payment_date': '14.09.2022',
#   'already_payed_amount': 8329,
#   'left_to_pay': 991671,
#   'one-time_payment': 166666,
#   'installment_amount': 1000000},
#  {'student_id': 273,
#   'student_name': 'Сидоров К.А.',
#   'installment': 'Y',
#   'last_payment_date': '28.09.2022',
#   'expected_payment_date': '27.03.2023',
#   'already_payed_amount': 11944,
#   'left_to_pay': 88056,
#   'one-time_payment': 16666,
#   'installment_amount': 100000},
#  {'student_id': 274,
#   'student_name': 'Иванов П.П.',
#   'installment': 'Y',
#   'last_payment_date': '19.10.2022',
#   'expected_payment_date': '17.04.2023',
#   'already_payed_amount': 22627,
#   'left_to_pay': 777373,
#   'one-time_payment': 133333,
#   'installment_amount': 800000},
#  {'student_id': 280,
#   'student_name': 'Николаева П.П.',
#   'installment': 'Y',
#   'last_payment_date': '06.04.2022',
#   'expected_payment_date': '03.10.2022',
#   'already_payed_amount': 22932,
#   'left_to_pay': 277068,
#   'one-time_payment': 25000,
#   'installment_amount': 300000},
#  {'student_id': 282,
#   'student_name': 'Сидоров Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '02.06.2022',
#   'expected_payment_date': '29.11.2022',
#   'already_payed_amount': 100397,
#   'left_to_pay': 399603,
#   'one-time_payment': 166666,
#   'installment_amount': 500000},
#  {'student_id': 283,
#   'student_name': 'Кузнецова П.П.',
#   'installment': 'Y',
#   'last_payment_date': '06.09.2022',
#   'expected_payment_date': '05.03.2023',
#   'already_payed_amount': 27752,
#   'left_to_pay': 772248,
#   'one-time_payment': 133333,
#   'installment_amount': 800000},
#  {'student_id': 287,
#   'student_name': 'Кузнецова К.А.',
#   'installment': 'Y',
#   'last_payment_date': '22.05.2022',
#   'expected_payment_date': '18.11.2022',
#   'already_payed_amount': 43194,
#   'left_to_pay': 256806,
#   'one-time_payment': 25000,
#   'installment_amount': 300000},
#  {'student_id': 290,
#   'student_name': 'Петров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '11.09.2022',
#   'expected_payment_date': '10.03.2023',
#   'already_payed_amount': 367435,
#   'left_to_pay': 632565,
#   'one-time_payment': 333333,
#   'installment_amount': 1000000},
#  {'student_id': 294,
#   'student_name': 'Петров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '30.03.2022',
#   'expected_payment_date': '26.09.2022',
#   'already_payed_amount': 140958,
#   'left_to_pay': 559042,
#   'one-time_payment': 116666,
#   'installment_amount': 700000},
#  {'student_id': 295,
#   'student_name': 'Сидоров М.А.',
#   'installment': 'Y',
#   'last_payment_date': '22.11.2022',
#   'expected_payment_date': '21.05.2023',
#   'already_payed_amount': 17673,
#   'left_to_pay': 482327,
#   'one-time_payment': 41666,
#   'installment_amount': 500000},
#  {'student_id': 297,
#   'student_name': 'Петров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '27.10.2022',
#   'expected_payment_date': '25.04.2023',
#   'already_payed_amount': 121637,
#   'left_to_pay': 778363,
#   'one-time_payment': 75000,
#   'installment_amount': 900000},
#  {'student_id': 298,
#   'student_name': 'Иванов П.П.',
#   'installment': 'Y',
#   'last_payment_date': '01.02.2022',
#   'expected_payment_date': '31.07.2022',
#   'already_payed_amount': 71423,
#   'left_to_pay': 828577,
#   'one-time_payment': 300000,
#   'installment_amount': 900000},
#  {'student_id': 300,
#   'student_name': 'Николаева А.А.',
#   'installment': 'Y',
#   'last_payment_date': '14.08.2022',
#   'expected_payment_date': '10.02.2023',
#   'already_payed_amount': 59555,
#   'left_to_pay': 140445,
#   'one-time_payment': 33333,
#   'installment_amount': 200000},
#  {'student_id': 301,
#   'student_name': 'Петров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '16.06.2022',
#   'expected_payment_date': '13.12.2022',
#   'already_payed_amount': 71445,
#   'left_to_pay': 928555,
#   'one-time_payment': 83333,
#   'installment_amount': 1000000},
#  {'student_id': 302,
#   'student_name': 'Петров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '31.12.2022',
#   'expected_payment_date': '29.06.2023',
#   'already_payed_amount': 6520,
#   'left_to_pay': 93480,
#   'one-time_payment': 8333,
#   'installment_amount': 100000},
#  {'student_id': 308,
#   'student_name': 'Смирнова Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '24.05.2022',
#   'expected_payment_date': '20.11.2022',
#   'already_payed_amount': 8518,
#   'left_to_pay': 191482,
#   'one-time_payment': 16666,
#   'installment_amount': 200000},
#  {'student_id': 309,
#   'student_name': 'Иванов П.П.',
#   'installment': 'Y',
#   'last_payment_date': '26.11.2022',
#   'expected_payment_date': '25.05.2023',
#   'already_payed_amount': 90942,
#   'left_to_pay': 209058,
#   'one-time_payment': 50000,
#   'installment_amount': 300000},
#  {'student_id': 311,
#   'student_name': 'Сидоров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '10.10.2022',
#   'expected_payment_date': '08.04.2023',
#   'already_payed_amount': 8219,
#   'left_to_pay': 591781,
#   'one-time_payment': 50000,
#   'installment_amount': 600000},
#  {'student_id': 313,
#   'student_name': 'Петров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '31.08.2022',
#   'expected_payment_date': '27.02.2023',
#   'already_payed_amount': 49122,
#   'left_to_pay': 950878,
#   'one-time_payment': 83333,
#   'installment_amount': 1000000},
#  {'student_id': 314,
#   'student_name': 'Иванов К.А.',
#   'installment': 'Y',
#   'last_payment_date': '25.12.2022',
#   'expected_payment_date': '23.06.2023',
#   'already_payed_amount': 15597,
#   'left_to_pay': 384403,
#   'one-time_payment': 33333,
#   'installment_amount': 400000},
#  {'student_id': 317,
#   'student_name': 'Кузнецова П.П.',
#   'installment': 'Y',
#   'last_payment_date': '09.08.2022',
#   'expected_payment_date': '05.02.2023',
#   'already_payed_amount': 10473,
#   'left_to_pay': 89527,
#   'one-time_payment': 8333,
#   'installment_amount': 100000},
#  {'student_id': 319,
#   'student_name': 'Николаева А.А.',
#   'installment': 'Y',
#   'last_payment_date': '12.03.2022',
#   'expected_payment_date': '08.09.2022',
#   'already_payed_amount': 5015,
#   'left_to_pay': 594985,
#   'one-time_payment': 50000,
#   'installment_amount': 600000},
#  {'student_id': 320,
#   'student_name': 'Кузнецова М.А.',
#   'installment': 'Y',
#   'last_payment_date': '30.09.2022',
#   'expected_payment_date': '29.03.2023',
#   'already_payed_amount': 4872,
#   'left_to_pay': 695128,
#   'one-time_payment': 58333,
#   'installment_amount': 700000},
#  {'student_id': 321,
#   'student_name': 'Смирнова И.И.',
#   'installment': 'Y',
#   'last_payment_date': '02.10.2022',
#   'expected_payment_date': '31.03.2023',
#   'already_payed_amount': 47270,
#   'left_to_pay': 152730,
#   'one-time_payment': 33333,
#   'installment_amount': 200000},
#  {'student_id': 324,
#   'student_name': 'Петров М.А.',
#   'installment': 'Y',
#   'last_payment_date': '28.01.2022',
#   'expected_payment_date': '27.07.2022',
#   'already_payed_amount': 16118,
#   'left_to_pay': 483882,
#   'one-time_payment': 166666,
#   'installment_amount': 500000},
#  {'student_id': 325,
#   'student_name': 'Николаева И.И.',
#   'installment': 'Y',
#   'last_payment_date': '24.10.2022',
#   'expected_payment_date': '22.04.2023',
#   'already_payed_amount': 69225,
#   'left_to_pay': 730775,
#   'one-time_payment': 66666,
#   'installment_amount': 800000},
#  {'student_id': 326,
#   'student_name': 'Сидоров Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '25.08.2022',
#   'expected_payment_date': '21.02.2023',
#   'already_payed_amount': 19574,
#   'left_to_pay': 480426,
#   'one-time_payment': 83333,
#   'installment_amount': 500000},
#  {'student_id': 330,
#   'student_name': 'Иванов М.А.',
#   'installment': 'Y',
#   'last_payment_date': '19.04.2022',
#   'expected_payment_date': '16.10.2022',
#   'already_payed_amount': 95633,
#   'left_to_pay': 204367,
#   'one-time_payment': 50000,
#   'installment_amount': 300000},
#  {'student_id': 332,
#   'student_name': 'Сидоров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '24.05.2022',
#   'expected_payment_date': '20.11.2022',
#   'already_payed_amount': 49664,
#   'left_to_pay': 50336,
#   'one-time_payment': 33333,
#   'installment_amount': 100000},
#  {'student_id': 333,
#   'student_name': 'Петров М.А.',
#   'installment': 'Y',
#   'last_payment_date': '27.06.2022',
#   'expected_payment_date': '24.12.2022',
#   'already_payed_amount': 23467,
#   'left_to_pay': 876533,
#   'one-time_payment': 75000,
#   'installment_amount': 900000},
#  {'student_id': 334,
#   'student_name': 'Петров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '11.04.2022',
#   'expected_payment_date': '08.10.2022',
#   'already_payed_amount': 146072,
#   'left_to_pay': 453928,
#   'one-time_payment': 100000,
#   'installment_amount': 600000},
#  {'student_id': 335,
#   'student_name': 'Иванов К.А.',
#   'installment': 'Y',
#   'last_payment_date': '04.09.2022',
#   'expected_payment_date': '03.03.2023',
#   'already_payed_amount': 55677,
#   'left_to_pay': 144323,
#   'one-time_payment': 33333,
#   'installment_amount': 200000},
#  {'student_id': 336,
#   'student_name': 'Петров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '27.01.2022',
#   'expected_payment_date': '26.07.2022',
#   'already_payed_amount': 146031,
#   'left_to_pay': 253969,
#   'one-time_payment': 133333,
#   'installment_amount': 400000},
#  {'student_id': 339,
#   'student_name': 'Смирнова К.А.',
#   'installment': 'Y',
#   'last_payment_date': '18.09.2022',
#   'expected_payment_date': '17.03.2023',
#   'already_payed_amount': 1702,
#   'left_to_pay': 98298,
#   'one-time_payment': 33333,
#   'installment_amount': 100000},
#  {'student_id': 340,
#   'student_name': 'Петров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '06.09.2022',
#   'expected_payment_date': '05.03.2023',
#   'already_payed_amount': 18230,
#   'left_to_pay': 381770,
#   'one-time_payment': 133333,
#   'installment_amount': 400000},
#  {'student_id': 344,
#   'student_name': 'Сидоров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '17.07.2022',
#   'expected_payment_date': '13.01.2023',
#   'already_payed_amount': 163807,
#   'left_to_pay': 236193,
#   'one-time_payment': 133333,
#   'installment_amount': 400000},
#  {'student_id': 347,
#   'student_name': 'Кузнецова К.А.',
# ...
#   'installment': 'Y',
#   'last_payment_date': '23.01.2022',
#   'expected_payment_date': '22.07.2022',
#   'already_payed_amount': 56935,
#   'left_to_pay': 943065,
#   'one-time_payment': 166666,
#   'installment_amount': 1000000},
#  {'student_id': 388,
#   'student_name': 'Николаева И.И.',
#   'installment': 'Y',
#   'last_payment_date': '04.12.2022',
#   'expected_payment_date': '02.06.2023',
#   'already_payed_amount': 25592,
#   'left_to_pay': 74408,
#   'one-time_payment': 33333,
#   'installment_amount': 100000},
#  {'student_id': 389,
#   'student_name': 'Смирнова П.П.',
#   'installment': 'Y',
#   'last_payment_date': '15.11.2022',
#   'expected_payment_date': '14.05.2023',
#   'already_payed_amount': 59400,
#   'left_to_pay': 740600,
#   'one-time_payment': 66666,
#   'installment_amount': 800000},
#  {'student_id': 390,
#   'student_name': 'Кузнецова Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '23.05.2022',
#   'expected_payment_date': '19.11.2022',
#   'already_payed_amount': 75528,
#   'left_to_pay': 424472,
#   'one-time_payment': 83333,
#   'installment_amount': 500000},
#  {'student_id': 391,
#   'student_name': 'Николаева К.А.',
#   'installment': 'Y',
#   'last_payment_date': '24.03.2022',
#   'expected_payment_date': '20.09.2022',
#   'already_payed_amount': 46122,
#   'left_to_pay': 653878,
#   'one-time_payment': 58333,
#   'installment_amount': 700000},
#  {'student_id': 392,
#   'student_name': 'Кузнецова М.А.',
#   'installment': 'Y',
#   'last_payment_date': '28.04.2022',
#   'expected_payment_date': '25.10.2022',
#   'already_payed_amount': 259568,
#   'left_to_pay': 240432,
#   'one-time_payment': 166666,
#   'installment_amount': 500000},
#  {'student_id': 394,
#   'student_name': 'Петров Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '15.08.2022',
#   'expected_payment_date': '11.02.2023',
#   'already_payed_amount': 37280,
#   'left_to_pay': 762720,
#   'one-time_payment': 133333,
#   'installment_amount': 800000},
#  {'student_id': 396,
#   'student_name': 'Смирнова П.П.',
#   'installment': 'Y',
#   'last_payment_date': '25.05.2022',
#   'expected_payment_date': '21.11.2022',
#   'already_payed_amount': 30996,
#   'left_to_pay': 469004,
#   'one-time_payment': 41666,
#   'installment_amount': 500000},
#  {'student_id': 398,
#   'student_name': 'Николаева А.А.',
#   'installment': 'Y',
#   'last_payment_date': '08.06.2022',
#   'expected_payment_date': '05.12.2022',
#   'already_payed_amount': 458378,
#   'left_to_pay': 341622,
#   'one-time_payment': 266666,
#   'installment_amount': 800000},
#  {'student_id': 400,
#   'student_name': 'Кузнецова Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '15.08.2022',
#   'expected_payment_date': '11.02.2023',
#   'already_payed_amount': 30617,
#   'left_to_pay': 69383,
#   'one-time_payment': 16666,
#   'installment_amount': 100000},
#  {'student_id': 406,
#   'student_name': 'Николаева М.А.',
#   'installment': 'Y',
#   'last_payment_date': '26.05.2022',
#   'expected_payment_date': '26.11.2022',
#   'already_payed_amount': 102130,
#   'left_to_pay': 297870,
#   'one-time_payment': 66666,
#   'installment_amount': 400000},
#  {'student_id': 407,
#   'student_name': 'Николаева К.А.',
#   'installment': 'Y',
#   'last_payment_date': '07.12.2022',
#   'expected_payment_date': '07.06.2023',
#   'already_payed_amount': 123824,
#   'left_to_pay': 776176,
#   'one-time_payment': 75000,
#   'installment_amount': 900000},
#  {'student_id': 408,
#   'student_name': 'Петров К.А.',
#   'installment': 'Y',
#   'last_payment_date': '02.04.2022',
#   'expected_payment_date': '02.10.2022',
#   'already_payed_amount': 1797,
#   'left_to_pay': 698203,
#   'one-time_payment': 58333,
#   'installment_amount': 700000},
#  {'student_id': 409,
#   'student_name': 'Иванов И.И.',
#   'installment': 'Y',
#   'last_payment_date': '26.04.2022',
#   'expected_payment_date': '23.10.2022',
#   'already_payed_amount': 26240,
#   'left_to_pay': 273760,
#   'one-time_payment': 50000,
#   'installment_amount': 300000},
#  {'student_id': 411,
#   'student_name': 'Кузнецова А.А.',
#   'installment': 'Y',
#   'last_payment_date': '11.12.2022',
#   'expected_payment_date': '11.06.2023',
#   'already_payed_amount': 141268,
#   'left_to_pay': 658732,
#   'one-time_payment': 133333,
#   'installment_amount': 800000},
#  {'student_id': 413,
#   'student_name': 'Николаева М.А.',
#   'installment': 'Y',
#   'last_payment_date': '22.07.2022',
#   'expected_payment_date': '22.01.2023',
#   'already_payed_amount': 222200,
#   'left_to_pay': 677800,
#   'one-time_payment': 300000,
#   'installment_amount': 900000},
#  {'student_id': 415,
#   'student_name': 'Сидоров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '06.09.2022',
#   'expected_payment_date': '06.03.2023',
#   'already_payed_amount': 150390,
#   'left_to_pay': 749610,
#   'one-time_payment': 150000,
#   'installment_amount': 900000},
#  {'student_id': 416,
#   'student_name': 'Сидоров К.А.',
#   'installment': 'Y',
#   'last_payment_date': '11.10.2022',
#   'expected_payment_date': '09.04.2023',
#   'already_payed_amount': 169651,
#   'left_to_pay': 530349,
#   'one-time_payment': 116666,
#   'installment_amount': 700000},
#  {'student_id': 419,
#   'student_name': 'Сидоров К.А.',
#   'installment': 'Y',
#   'last_payment_date': '08.10.2022',
#   'expected_payment_date': '06.04.2023',
#   'already_payed_amount': 72441,
#   'left_to_pay': 427559,
#   'one-time_payment': 166666,
#   'installment_amount': 500000},
#  {'student_id': 420,
#   'student_name': 'Сидоров М.А.',
#   'installment': 'Y',
#   'last_payment_date': '14.07.2022',
#   'expected_payment_date': '14.01.2023',
#   'already_payed_amount': 97156,
#   'left_to_pay': 502844,
#   'one-time_payment': 100000,
#   'installment_amount': 600000},
#  {'student_id': 421,
#   'student_name': 'Смирнова А.А.',
#   'installment': 'Y',
#   'last_payment_date': '16.12.2022',
#   'expected_payment_date': '16.06.2023',
#   'already_payed_amount': 44027,
#   'left_to_pay': 455973,
#   'one-time_payment': 41666,
#   'installment_amount': 500000},
#  {'student_id': 422,
#   'student_name': 'Кузнецова Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '10.01.2022',
#   'expected_payment_date': '10.07.2022',
#   'already_payed_amount': 74457,
#   'left_to_pay': 625543,
#   'one-time_payment': 58333,
#   'installment_amount': 700000},
#  {'student_id': 425,
#   'student_name': 'Николаева К.А.',
#   'installment': 'Y',
#   'last_payment_date': '13.02.2022',
#   'expected_payment_date': '12.08.2022',
#   'already_payed_amount': 14216,
#   'left_to_pay': 385784,
#   'one-time_payment': 66666,
#   'installment_amount': 400000},
#  {'student_id': 426,
#   'student_name': 'Сидоров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '06.02.2022',
#   'expected_payment_date': '06.08.2022',
#   'already_payed_amount': 3096,
#   'left_to_pay': 496904,
#   'one-time_payment': 41666,
#   'installment_amount': 500000},
#  {'student_id': 428,
#   'student_name': 'Иванов К.А.',
#   'installment': 'Y',
#   'last_payment_date': '06.11.2022',
#   'expected_payment_date': '06.05.2023',
#   'already_payed_amount': 126121,
#   'left_to_pay': 573879,
#   'one-time_payment': 116666,
#   'installment_amount': 700000},
#  {'student_id': 429,
#   'student_name': 'Петров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '07.04.2022',
#   'expected_payment_date': '07.10.2022',
#   'already_payed_amount': 16222,
#   'left_to_pay': 83778,
#   'one-time_payment': 8333,
#   'installment_amount': 100000},
#  {'student_id': 430,
#   'student_name': 'Сидоров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '11.10.2022',
#   'expected_payment_date': '11.04.2023',
#   'already_payed_amount': 96704,
#   'left_to_pay': 203296,
#   'one-time_payment': 50000,
#   'installment_amount': 300000},
#  {'student_id': 433,
#   'student_name': 'Смирнова Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '01.02.2022',
#   'expected_payment_date': '01.08.2022',
#   'already_payed_amount': 8010,
#   'left_to_pay': 591990,
#   'one-time_payment': 200000,
#   'installment_amount': 600000},
#  {'student_id': 436,
#   'student_name': 'Иванов П.П.',
#   'installment': 'Y',
#   'last_payment_date': '13.07.2022',
#   'expected_payment_date': '09.01.2023',
#   'already_payed_amount': 12834,
#   'left_to_pay': 487166,
#   'one-time_payment': 83333,
#   'installment_amount': 500000},
#  {'student_id': 438,
#   'student_name': 'Иванов М.А.',
#   'installment': 'Y',
#   'last_payment_date': '29.06.2022',
#   'expected_payment_date': '26.12.2022',
#   'already_payed_amount': 317476,
#   'left_to_pay': 682524,
#   'one-time_payment': 166666,
#   'installment_amount': 1000000},
#  {'student_id': 444,
#   'student_name': 'Иванов А.А.',
#   'installment': 'Y',
#   'last_payment_date': '03.01.2022',
#   'expected_payment_date': '03.07.2022',
#   'already_payed_amount': 154095,
#   'left_to_pay': 745905,
#   'one-time_payment': 150000,
#   'installment_amount': 900000},
#  {'student_id': 445,
#   'student_name': 'Сидоров М.А.',
#   'installment': 'Y',
#   'last_payment_date': '18.09.2022',
#   'expected_payment_date': '17.03.2023',
#   'already_payed_amount': 220263,
#   'left_to_pay': 779737,
#   'one-time_payment': 333333,
#   'installment_amount': 1000000},
#  {'student_id': 447,
#   'student_name': 'Кузнецова А.А.',
#   'installment': 'Y',
#   'last_payment_date': '06.01.2022',
#   'expected_payment_date': '06.07.2022',
#   'already_payed_amount': 180068,
#   'left_to_pay': 619932,
#   'one-time_payment': 266666,
#   'installment_amount': 800000},
#  {'student_id': 449,
#   'student_name': 'Кузнецова Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '21.08.2022',
#   'expected_payment_date': '21.02.2023',
#   'already_payed_amount': 131147,
#   'left_to_pay': 668853,
#   'one-time_payment': 66666,
#   'installment_amount': 800000},
#  {'student_id': 450,
#   'student_name': 'Кузнецова А.А.',
#   'installment': 'Y',
#   'last_payment_date': '12.02.2022',
#   'expected_payment_date': '12.08.2022',
#   'already_payed_amount': 40631,
#   'left_to_pay': 459369,
#   'one-time_payment': 41666,
#   'installment_amount': 500000},
#  {'student_id': 451,
#   'student_name': 'Смирнова П.П.',
#   'installment': 'Y',
#   'last_payment_date': '15.10.2022',
#   'expected_payment_date': '15.04.2023',
#   'already_payed_amount': 26904,
#   'left_to_pay': 473096,
#   'one-time_payment': 41666,
#   'installment_amount': 500000},
#  {'student_id': 452,
#   'student_name': 'Петров Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '08.12.2022',
#   'expected_payment_date': '06.06.2023',
#   'already_payed_amount': 29695,
#   'left_to_pay': 170305,
#   'one-time_payment': 16666,
#   'installment_amount': 200000},
#  {'student_id': 453,
#   'student_name': 'Петров К.А.',
#   'installment': 'Y',
#   'last_payment_date': '08.04.2022',
#   'expected_payment_date': '08.10.2022',
#   'already_payed_amount': 6019,
#   'left_to_pay': 593981,
#   'one-time_payment': 50000,
#   'installment_amount': 600000},
#  {'student_id': 454,
#   'student_name': 'Кузнецова М.А.',
#   'installment': 'Y',
#   'last_payment_date': '24.03.2022',
#   'expected_payment_date': '24.09.2022',
#   'already_payed_amount': 147212,
#   'left_to_pay': 452788,
#   'one-time_payment': 100000,
#   'installment_amount': 600000},
#  {'student_id': 459,
#   'student_name': 'Смирнова П.П.',
#   'installment': 'Y',
#   'last_payment_date': '02.12.2022',
#   'expected_payment_date': '02.06.2023',
#   'already_payed_amount': 6928,
#   'left_to_pay': 93072,
#   'one-time_payment': 8333,
#   'installment_amount': 100000},
#  {'student_id': 461,
#   'student_name': 'Николаева П.П.',
#   'installment': 'Y',
#   'last_payment_date': '26.09.2022',
#   'expected_payment_date': '26.03.2023',
#   'already_payed_amount': 22812,
#   'left_to_pay': 277188,
#   'one-time_payment': 25000,
#   'installment_amount': 300000},
#  {'student_id': 462,
#   'student_name': 'Николаева П.П.',
#   'installment': 'Y',
#   'last_payment_date': '26.10.2022',
#   'expected_payment_date': '26.04.2023',
#   'already_payed_amount': 48238,
#   'left_to_pay': 251762,
#   'one-time_payment': 25000,
#   'installment_amount': 300000},
#  {'student_id': 465,
#   'student_name': 'Сидоров И.И.',
#   'installment': 'Y',
#   'last_payment_date': '14.04.2022',
#   'expected_payment_date': '14.10.2022',
#   'already_payed_amount': 230189,
#   'left_to_pay': 769811,
#   'one-time_payment': 333333,
#   'installment_amount': 1000000},
#  {'student_id': 466,
#   'student_name': 'Николаева П.П.',
#   'installment': 'Y',
#   'last_payment_date': '25.03.2022',
#   'expected_payment_date': '25.09.2022',
#   'already_payed_amount': 15577,
#   'left_to_pay': 84423,
#   'one-time_payment': 16666,
#   'installment_amount': 100000},
#  {'student_id': 467,
#   'student_name': 'Сидоров Е.В.',
#   'installment': 'Y',
#   'last_payment_date': '09.01.2022',
#   'expected_payment_date': '08.07.2022',
#   'already_payed_amount': 188136,
#   'left_to_pay': 711864,
#   'one-time_payment': 300000,
#   'installment_amount': 900000},
#  {'student_id': 469,
#   'student_name': 'Петров К.А.',
#   'installment': 'Y',
#   'last_payment_date': '10.12.2022',
#   'expected_payment_date': '10.06.2023',
#   'already_payed_amount': 30657,
#   'left_to_pay': 369343,
#   'one-time_payment': 33333,
#   'installment_amount': 400000},
#  {'student_id': 471,
#   'student_name': 'Иванов М.А.',
#   'installment': 'Y',
#   'last_payment_date': '02.01.2022',
#   'expected_payment_date': '02.07.2022',
#   'already_payed_amount': 196251,
#   'left_to_pay': 403749,
#   'one-time_payment': 100000,
#   'installment_amount': 600000},
#  {'student_id': 472,
#   'student_name': 'Николаева А.А.',
#   'installment': 'Y',
#   'last_payment_date': '15.04.2022',
#   'expected_payment_date': '15.10.2022',
#   'already_payed_amount': 46680,
#   'left_to_pay': 553320,
#   'one-time_payment': 100000,
#   'installment_amount': 600000},
#  {'student_id': 473,
#   'student_name': 'Сидоров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '05.06.2022',
#   'expected_payment_date': '02.12.2022',
#   'already_payed_amount': 137263,
#   'left_to_pay': 362737,
#   'one-time_payment': 166666,
#   'installment_amount': 500000},
#  {'student_id': 474,
#   'student_name': 'Сидоров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '06.01.2022',
#   'expected_payment_date': '06.07.2022',
#   'already_payed_amount': 5323,
#   'left_to_pay': 994677,
#   'one-time_payment': 333333,
#   'installment_amount': 1000000},
#  {'student_id': 480,
#   'student_name': 'Смирнова К.А.',
#   'installment': 'Y',
#   'last_payment_date': '17.07.2022',
#   'expected_payment_date': '17.01.2023',
#   'already_payed_amount': 127000,
#   'left_to_pay': 673000,
#   'one-time_payment': 133333,
#   'installment_amount': 800000},
#  {'student_id': 482,
#   'student_name': 'Сидоров К.А.',
#   'installment': 'Y',
#   'last_payment_date': '23.09.2022',
#   'expected_payment_date': '22.03.2023',
#   'already_payed_amount': 75732,
#   'left_to_pay': 924268,
#   'one-time_payment': 83333,
#   'installment_amount': 1000000},
#  {'student_id': 483,
#   'student_name': 'Сидоров А.А.',
#   'installment': 'Y',
#   'last_payment_date': '12.06.2022',
#   'expected_payment_date': '12.12.2022',
#   'already_payed_amount': 520614,
#   'left_to_pay': 279386,
#   'one-time_payment': 266666,
#   'installment_amount': 800000},
#  {'student_id': 490,
#   'student_name': 'Иванов М.А.',
#   'installment': 'Y',
#   'last_payment_date': '02.06.2022',
#   'expected_payment_date': '02.12.2022',
#   'already_payed_amount': 45836,
#   'left_to_pay': 254164,
#   'one-time_payment': 25000,
#   'installment_amount': 300000},
#  {'student_id': 493,
#   'student_name': 'Иванов И.И.',
#   'installment': 'Y',
#   'last_payment_date': '30.09.2022',
#   'expected_payment_date': '29.03.2023',
#   'already_payed_amount': 14272,
#   'left_to_pay': 185728,
#   'one-time_payment': 16666,
#   'installment_amount': 200000},
#  {'student_id': 494,
#   'student_name': 'Иванов М.А.',
#   'installment': 'Y',
#   'last_payment_date': '12.02.2022',
#   'expected_payment_date': '12.08.2022',
#   'already_payed_amount': 312773,
#   'left_to_pay': 387227,
#   'one-time_payment': 233333,
#   'installment_amount': 700000},
#  {'student_id': 495,
#   'student_name': 'Николаева М.А.',
#   'installment': 'Y',
#   'last_payment_date': '29.04.2022',
#   'expected_payment_date': '29.10.2022',
#   'already_payed_amount': 25117,
#   'left_to_pay': 174883,
#   'one-time_payment': 33333,
#   'installment_amount': 200000},
#  {'student_id': 499,
#   'student_name': 'Сидоров П.П.',
#   'installment': 'Y',
#   'last_payment_date': '12.04.2022',
#   'expected_payment_date': '12.10.2022',
#   'already_payed_amount': 232915,
#   'left_to_pay': 767085,
#   'one-time_payment': 333333,
#   'installment_amount': 1000000}]
